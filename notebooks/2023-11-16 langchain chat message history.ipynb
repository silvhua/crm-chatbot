# %% [markdown]
# # Title
# []()

# %%
import pandas as pd
import sys
sys.path.append(r"C:\Users\silvh\OneDrive\lighthouse\custom_python")
from silvhua import *
# from datetime import datetime
# sys.path.append(r"C:\Users\silvh\OneDrive\lighthouse\portfolio-projects\online-PT-social-media-NLP\src")

# %% [markdown]
# # Initiate dicts

# %%
import json
with open('../src/private/contacts.json') as file:
    contacts = json.load(file)

# %%
query_dict = dict()
contactId = contacts['me']

# %% [markdown]
# # Copied from Nov 12 notebook

# %%
import boto3
from boto3.dynamodb.conditions import Key


def query_dynamodb_table(
    table_name, partition_key_value, sort_key_value='', partition_key='SessionId', sort_key=None, 
    profile='mcgill_credentials', region_name="us-west-2"
    ):
    """
    Query a Dynamodb table based on both the partition key and sort key.
    Parameters:
        table_name (str): The name of the DynamoDB table.
        partition_key_value (str): The value of the partition key.
        sort_key_value (str): The value of the sort key.
        partition_key (str): The name of the partition key.
        sort_key (str): The name of the sort key.
        region_name (str): The name of the AWS region.

    Returns:
        dict: The results of the query. The 'Items' key contains the table record.       
    From 2023-10-22 notebook.
    """
    if profile:
        session = boto3.Session(profile_name=profile)
        dynamodb = session.resource('dynamodb', region_name=region_name)
    else:
        dynamodb = boto3.resource('dynamodb', region_name=region_name)
    table = dynamodb.Table(table_name)
    if sort_key:
        KeyConditionExpression = Key(partition_key).eq(partition_key_value) & Key(sort_key).eq(sort_key_value)
    else:
        KeyConditionExpression = Key(partition_key).eq(partition_key_value)
    print(f'KeyConditionExpression: {KeyConditionExpression}')
    response = table.query(
        KeyConditionExpression=KeyConditionExpression,
    )
    return response

iteration = 1.1
query_dict[iteration] = query_dynamodb_table('SessionTable', contactId, 'ChatHistory')
query_dict[iteration]

# %% [markdown]
# ## 1.2

# %%
import boto3
from boto3.dynamodb.conditions import Key
from langchain.memory.chat_message_histories import DynamoDBChatMessageHistory
from langchain.memory import ConversationBufferMemory

def query_dynamodb_table(
    table_name, partition_key_value, sort_key_value='', partition_key='SessionId', sort_key=None, 
    profile='mcgill_credentials', region_name="us-west-2"
    ):
    """
    Query a Dynamodb table based on both the partition key and sort key.
    Parameters:
        table_name (str): The name of the DynamoDB table.
        partition_key_value (str): The value of the partition key.
        sort_key_value (str): The value of the sort key.
        partition_key (str): The name of the partition key.
        sort_key (str): The name of the sort key.
        region_name (str): The name of the AWS region.

    Returns:
        dict: The results of the query. The 'Items' key contains the table record.       
    From 2023-10-22 notebook.
    """
    if profile:
        session = boto3.Session(profile_name=profile)
        dynamodb = session.resource('dynamodb', region_name=region_name)
    else:
        dynamodb = boto3.resource('dynamodb', region_name=region_name)
    table = dynamodb.Table(table_name)
    if sort_key:
        KeyConditionExpression = Key(partition_key).eq(partition_key_value) & Key(sort_key).eq(sort_key_value)
    else:
        KeyConditionExpression = Key(partition_key).eq(partition_key_value)
    print(f'KeyConditionExpression: {KeyConditionExpression}')
    response = table.query(
        KeyConditionExpression=KeyConditionExpression,
    )
    return response

def dynamodb_chat_history(contactId):
    message_history = DynamoDBChatMessageHistory(
        table_name="SessionTable", session_id=contactId,
        key={
            "PK": "SessionId",
            "SK": "type",
            }
        )
    return message_history

iteration = 1.2
query_dict[iteration] = dynamodb_chat_history(contactId)
query_dict[iteration]

# %%
query_dict[iteration].messages
# Out:
# An error occurred (ValidationException) when calling the GetItem operation: The provided key element does not match the schema
# []

# %% [markdown]
# ## 1.21

# %%
import boto3
from boto3.dynamodb.conditions import Key
from langchain.memory.chat_message_histories import DynamoDBChatMessageHistory
from langchain.memory import ConversationBufferMemory

def query_dynamodb_table(
    table_name, partition_key_value, sort_key_value='', partition_key='SessionId', sort_key=None, 
    profile='mcgill_credentials', region_name="us-west-2"
    ):
    """
    Query a Dynamodb table based on both the partition key and sort key.
    Parameters:
        table_name (str): The name of the DynamoDB table.
        partition_key_value (str): The value of the partition key.
        sort_key_value (str): The value of the sort key.
        partition_key (str): The name of the partition key.
        sort_key (str): The name of the sort key.
        region_name (str): The name of the AWS region.

    Returns:
        dict: The results of the query. The 'Items' key contains the table record.       
    From 2023-10-22 notebook.
    """
    if profile:
        session = boto3.Session(profile_name=profile)
        dynamodb = session.resource('dynamodb', region_name=region_name)
    else:
        dynamodb = boto3.resource('dynamodb', region_name=region_name)
    table = dynamodb.Table(table_name)
    if sort_key:
        KeyConditionExpression = Key(partition_key).eq(partition_key_value) & Key(sort_key).eq(sort_key_value)
    else:
        KeyConditionExpression = Key(partition_key).eq(partition_key_value)
    print(f'KeyConditionExpression: {KeyConditionExpression}')
    response = table.query(
        KeyConditionExpression=KeyConditionExpression,
    )
    return response

def dynamodb_chat_history(contactId):
    message_history = DynamoDBChatMessageHistory(
        table_name="SessionTable", session_id=contactId,
        key={
            "PK": contactId,
            "SK": 'ChatHistory',
            }
        )
    return message_history.messages

iteration = 1.2
query_dict[iteration] = dynamodb_chat_history(contactId)
query_dict[iteration]
# Out:
# An error occurred (ValidationException) when calling the GetItem operation: The provided key element does not match the schema
# []

# %% [markdown]
# ## 1.22

# %%
import boto3
from boto3.dynamodb.conditions import Key
from langchain.memory.chat_message_histories import DynamoDBChatMessageHistory
from langchain.memory import ConversationBufferMemory

def query_dynamodb_table(
    table_name, partition_key_value, sort_key_value='', partition_key='SessionId', sort_key=None, 
    profile='mcgill_credentials', region_name="us-west-2"
    ):
    """
    Query a Dynamodb table based on both the partition key and sort key.
    Parameters:
        table_name (str): The name of the DynamoDB table.
        partition_key_value (str): The value of the partition key.
        sort_key_value (str): The value of the sort key.
        partition_key (str): The name of the partition key.
        sort_key (str): The name of the sort key.
        region_name (str): The name of the AWS region.

    Returns:
        dict: The results of the query. The 'Items' key contains the table record.       
    From 2023-10-22 notebook.
    """
    if profile:
        session = boto3.Session(profile_name=profile)
        dynamodb = session.resource('dynamodb', region_name=region_name)
    else:
        dynamodb = boto3.resource('dynamodb', region_name=region_name)
    table = dynamodb.Table(table_name)
    if sort_key:
        KeyConditionExpression = Key(partition_key).eq(partition_key_value) & Key(sort_key).eq(sort_key_value)
    else:
        KeyConditionExpression = Key(partition_key).eq(partition_key_value)
    print(f'KeyConditionExpression: {KeyConditionExpression}')
    response = table.query(
        KeyConditionExpression=KeyConditionExpression,
    )
    return response

def dynamodb_chat_history(contactId):
    message_history = DynamoDBChatMessageHistory(
        table_name="SessionTable", session_id=contactId,
        key={
            "SessionId": contactId,
            "type": 'ChatHistory',
            }
        )
    return message_history.messages

iteration = 1.22
query_dict[iteration] = dynamodb_chat_history(contactId)
query_dict[iteration]
# Out:
# An error occurred (ValidationException) when calling the GetItem operation: The provided key element does not match the schema
# []

# %% [markdown]
# ## 1.23

# %%
import boto3
from boto3.dynamodb.conditions import Key
from langchain.memory.chat_message_histories import DynamoDBChatMessageHistory
from langchain.memory import ConversationBufferMemory

def query_dynamodb_table(
    table_name, partition_key_value, sort_key_value='', partition_key='SessionId', sort_key=None, 
    profile='mcgill_credentials', region_name="us-west-2"
    ):
    """
    Query a Dynamodb table based on both the partition key and sort key.
    Parameters:
        table_name (str): The name of the DynamoDB table.
        partition_key_value (str): The value of the partition key.
        sort_key_value (str): The value of the sort key.
        partition_key (str): The name of the partition key.
        sort_key (str): The name of the sort key.
        region_name (str): The name of the AWS region.

    Returns:
        dict: The results of the query. The 'Items' key contains the table record.       
    From 2023-10-22 notebook.
    """
    if profile:
        session = boto3.Session(profile_name=profile)
        dynamodb = session.resource('dynamodb', region_name=region_name)
    else:
        dynamodb = boto3.resource('dynamodb', region_name=region_name)
    table = dynamodb.Table(table_name)
    if sort_key:
        KeyConditionExpression = Key(partition_key).eq(partition_key_value) & Key(sort_key).eq(sort_key_value)
    else:
        KeyConditionExpression = Key(partition_key).eq(partition_key_value)
    print(f'KeyConditionExpression: {KeyConditionExpression}')
    response = table.query(
        KeyConditionExpression=KeyConditionExpression,
    )
    return response

def dynamodb_chat_history(contactId):
    message_history = DynamoDBChatMessageHistory(
        table_name="SessionTable", 
        key={
            "SessionId": contactId,
            "type": 'ChatHistory',
            }
        )
    return message_history.messages

iteration = 1.23
query_dict[iteration] = dynamodb_chat_history(contactId)
query_dict[iteration]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\silvh\OneDrive\lighthouse\portfolio-projects\GHL-chat\notebooks\2023-11-16 langchain chat message history.ipynb Cell 16 line 5
#      <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X12sZmlsZQ%3D%3D?line=47'>48</a>     return message_history.messages
#      <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X12sZmlsZQ%3D%3D?line=49'>50</a> iteration = 1.23
# ---> <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X12sZmlsZQ%3D%3D?line=50'>51</a> query_dict[iteration] = dynamodb_chat_history(contactId)
#      <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X12sZmlsZQ%3D%3D?line=51'>52</a> query_dict[iteration]
#
# c:\Users\silvh\OneDrive\lighthouse\portfolio-projects\GHL-chat\notebooks\2023-11-16 langchain chat message history.ipynb Cell 16 line 4
#      <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X12sZmlsZQ%3D%3D?line=39'>40</a> def dynamodb_chat_history(contactId):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X12sZmlsZQ%3D%3D?line=40'>41</a>     message_history = DynamoDBChatMessageHistory(
#      <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X12sZmlsZQ%3D%3D?line=41'>42</a>         table_name="SessionTable",
#      <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X12sZmlsZQ%3D%3D?line=42'>43</a>         key={
#      <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X12sZmlsZQ%3D%3D?line=43'>44</a>             "SessionId": contactId,
#      <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X12sZmlsZQ%3D%3D?line=44'>45</a>             "type": 'ChatHistory',
#      <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X12sZmlsZQ%3D%3D?line=45'>46</a>             }
#      <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X12sZmlsZQ%3D%3D?line=46'>47</a>         )
#      <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X12sZmlsZQ%3D%3D?line=47'>48</a>     return message_history.messages
#
# TypeError: DynamoDBChatMessageHistory.__init__() missing 1 required positional argument: 'session_id'

# %% [markdown]
# ## 1.24 Response is from the table in the wrong AWS account (original AWS account instead of silvia-mcgill account)

# %%
import boto3
from boto3.dynamodb.conditions import Key
from langchain.memory.chat_message_histories import DynamoDBChatMessageHistory
from langchain.memory import ConversationBufferMemory

def query_dynamodb_table(
    table_name, partition_key_value, sort_key_value='', partition_key='SessionId', sort_key=None, 
    profile='mcgill_credentials', region_name="us-west-2"
    ):
    """
    Query a Dynamodb table based on both the partition key and sort key.
    Parameters:
        table_name (str): The name of the DynamoDB table.
        partition_key_value (str): The value of the partition key.
        sort_key_value (str): The value of the sort key.
        partition_key (str): The name of the partition key.
        sort_key (str): The name of the sort key.
        region_name (str): The name of the AWS region.

    Returns:
        dict: The results of the query. The 'Items' key contains the table record.       
    From 2023-10-22 notebook.
    """
    if profile:
        session = boto3.Session(profile_name=profile)
        dynamodb = session.resource('dynamodb', region_name=region_name)
    else:
        dynamodb = boto3.resource('dynamodb', region_name=region_name)
    table = dynamodb.Table(table_name)
    if sort_key:
        KeyConditionExpression = Key(partition_key).eq(partition_key_value) & Key(sort_key).eq(sort_key_value)
    else:
        KeyConditionExpression = Key(partition_key).eq(partition_key_value)
    print(f'KeyConditionExpression: {KeyConditionExpression}')
    response = table.query(
        KeyConditionExpression=KeyConditionExpression,
    )
    return response

def dynamodb_chat_history(contactId):
    message_history = DynamoDBChatMessageHistory(
        table_name="SessionTable", session_id=contactId,
        # key={
        #     "SessionId": contactId,
        #     "type": 'ChatHistory',
        #     }
        )
    return message_history.messages

iteration = 1.22
query_dict[iteration] = dynamodb_chat_history(contactId)
query_dict[iteration]
# Out:
# No record found with session id: C3a796qLEF4HtDjvKJ1K
# []

# %% [markdown]
# ## 1.4 after deleting SessionTable in original AWS account

# %%
import boto3
from boto3.dynamodb.conditions import Key
from langchain.memory.chat_message_histories import DynamoDBChatMessageHistory
from langchain.memory import ConversationBufferMemory

def query_dynamodb_table(
    table_name, partition_key_value, sort_key_value='', partition_key='SessionId', sort_key=None, 
    profile='mcgill_credentials', region_name="us-west-2"
    ):
    """
    Query a Dynamodb table based on both the partition key and sort key.
    Parameters:
        table_name (str): The name of the DynamoDB table.
        partition_key_value (str): The value of the partition key.
        sort_key_value (str): The value of the sort key.
        partition_key (str): The name of the partition key.
        sort_key (str): The name of the sort key.
        region_name (str): The name of the AWS region.

    Returns:
        dict: The results of the query. The 'Items' key contains the table record.       
    From 2023-10-22 notebook.
    """
    if profile:
        session = boto3.Session(profile_name=profile)
        dynamodb = session.resource('dynamodb', region_name=region_name)
    else:
        dynamodb = boto3.resource('dynamodb', region_name=region_name)
    table = dynamodb.Table(table_name)
    if sort_key:
        KeyConditionExpression = Key(partition_key).eq(partition_key_value) & Key(sort_key).eq(sort_key_value)
    else:
        KeyConditionExpression = Key(partition_key).eq(partition_key_value)
    print(f'KeyConditionExpression: {KeyConditionExpression}')
    response = table.query(
        KeyConditionExpression=KeyConditionExpression,
    )
    return response

def dynamodb_chat_history(contactId):
    message_history = DynamoDBChatMessageHistory(
        table_name="SessionTable", session_id=contactId,
        key={
            "SessionId": contactId,
            "type": 'ChatHistory',
            }
        )
    return message_history.messages

iteration = 1.24
query_dict[iteration] = dynamodb_chat_history(contactId)
query_dict[iteration]
# Out:
# No record found with session id: C3a796qLEF4HtDjvKJ1K
# []

# %%
iteration = 1.241
query_dict[iteration] = dynamodb_chat_history('test')
query_dict[iteration]
# Out:
# No record found with session id: test
# []

# %% [markdown]
# ## 1.25

# %%
import boto3
from boto3.dynamodb.conditions import Key
from langchain.memory.chat_message_histories import DynamoDBChatMessageHistory
from langchain.memory import ConversationBufferMemory

def query_dynamodb_table(
    partition_key_value, table_name='SessionTable', sort_key_value='', partition_key='SessionId', sort_key=None, 
    profile='mcgill_credentials', region_name="us-west-2"
    ):
    """
    Query a Dynamodb table based on both the partition key and sort key.
    Parameters:
        table_name (str): The name of the DynamoDB table.
        partition_key_value (str): The value of the partition key.
        sort_key_value (str): The value of the sort key.
        partition_key (str): The name of the partition key.
        sort_key (str): The name of the sort key.
        region_name (str): The name of the AWS region.

    Returns:
        dict: The results of the query. The 'Items' key contains the table record.       
    From 2023-10-22 notebook.
    """
    if profile:
        session = boto3.Session(profile_name=profile)
        dynamodb = session.resource('dynamodb', region_name=region_name)
    else:
        dynamodb = boto3.resource('dynamodb', region_name=region_name)
    table = dynamodb.Table(table_name)
    if sort_key:
        KeyConditionExpression = Key(partition_key).eq(partition_key_value) & Key(sort_key).eq(sort_key_value)
    else:
        KeyConditionExpression = Key(partition_key).eq(partition_key_value)
    print(f'KeyConditionExpression: {KeyConditionExpression}')
    response = table.query(
        KeyConditionExpression=KeyConditionExpression,
    )
    return response

def dynamodb_chat_history(contactId):
    message_history = DynamoDBChatMessageHistory(
        table_name="SessionTable", session_id=contactId,
        key={
            "SessionId": contactId,
            "type": 'ChatHistory',
            }
        )
    return message_history.messages

iteration = 1.25
# query_dict[iteration] = dynamodb_chat_history(contactId)
query_dict[iteration] = query_dynamodb_table(contactId, 'ChatHistory')
query_dict[iteration]
# Out:
# KeyConditionExpression: <boto3.dynamodb.conditions.Equals object at 0x000002309AAB2210>
# ---------------------------------------------------------------------------
# ResourceNotFoundException                 Traceback (most recent call last)
# c:\Users\silvh\OneDrive\lighthouse\portfolio-projects\GHL-chat\notebooks\2023-11-16 langchain chat message history.ipynb Cell 23 line 5
#      <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X15sZmlsZQ%3D%3D?line=49'>50</a> iteration = 1.25
#      <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X15sZmlsZQ%3D%3D?line=50'>51</a> # query_dict[iteration] = dynamodb_chat_history(contactId)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X15sZmlsZQ%3D%3D?line=51'>52</a> query_dict[iteration] = query_dynamodb_table(contactId, 'ChatHistory')
#      <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X15sZmlsZQ%3D%3D?line=52'>53</a> query_dict[iteration]
#
# c:\Users\silvh\OneDrive\lighthouse\portfolio-projects\GHL-chat\notebooks\2023-11-16 langchain chat message history.ipynb Cell 23 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X15sZmlsZQ%3D%3D?line=32'>33</a>     KeyConditionExpression = Key(partition_key).eq(partition_key_value)
#      <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X15sZmlsZQ%3D%3D?line=33'>34</a> print(f'KeyConditionExpression: {KeyConditionExpression}')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X15sZmlsZQ%3D%3D?line=34'>35</a> response = table.query(
#      <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X15sZmlsZQ%3D%3D?line=35'>36</a>     KeyConditionExpression=KeyConditionExpression,
#      <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X15sZmlsZQ%3D%3D?line=36'>37</a> )
#      <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X15sZmlsZQ%3D%3D?line=37'>38</a> return response
#
# File c:\Users\silvh\.conda\envs\projects\Lib\site-packages\boto3\resources\factory.py:580, in ResourceFactory._create_action.<locals>.do_action(self, *args, **kwargs)
#     579 def do_action(self, *args, **kwargs):
# --> 580     response = action(self, *args, **kwargs)
#     582     if hasattr(self, 'load'):
#     583         # Clear cached data. It will be reloaded the next
#     584         # time that an attribute is accessed.
#     585         # TODO: Make this configurable in the future?
#     586         self.meta.data = None
#
# File c:\Users\silvh\.conda\envs\projects\Lib\site-packages\boto3\resources\action.py:88, in ServiceAction.__call__(self, parent, *args, **kwargs)
#      79 params.update(kwargs)
#      81 logger.debug(
#      82     'Calling %s:%s with %r',
#      83     parent.meta.service_name,
#      84     operation_name,
#      85     params,
#      86 )
# ---> 88 response = getattr(parent.meta.client, operation_name)(*args, **params)
#      90 logger.debug('Response: %r', response)
#      92 return self._response_handler(parent, params, response)
#
# File c:\Users\silvh\.conda\envs\projects\Lib\site-packages\botocore\client.py:535, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     531     raise TypeError(
#     532         f"{py_operation_name}() only accepts keyword arguments."
#     533     )
#     534 # The "self" in this scope is referring to the BaseClient.
# --> 535 return self._make_api_call(operation_name, kwargs)
#
# File c:\Users\silvh\.conda\envs\projects\Lib\site-packages\botocore\client.py:980, in BaseClient._make_api_call(self, operation_name, api_params)
#     978     error_code = parsed_response.get("Error", {}).get("Code")
#     979     error_class = self.exceptions.from_code(error_code)
# --> 980     raise error_class(parsed_response, operation_name)
#     981 else:
#     982     return parsed_response
#
# ResourceNotFoundException: An error occurred (ResourceNotFoundException) when calling the Query operation: Requested resource not found

# %%
iteration = 1.251
# query_dict[iteration] = dynamodb_chat_history(contactId)
query_dict[iteration] = query_dynamodb_table(contactId, 'ChatHistory', profile='default')
query_dict[iteration]
# Out:
# KeyConditionExpression: <boto3.dynamodb.conditions.Equals object at 0x000002309A51D210>
# ---------------------------------------------------------------------------
# ResourceNotFoundException                 Traceback (most recent call last)
# c:\Users\silvh\OneDrive\lighthouse\portfolio-projects\GHL-chat\notebooks\2023-11-16 langchain chat message history.ipynb Cell 24 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X61sZmlsZQ%3D%3D?line=0'>1</a> iteration = 1.251
#       <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X61sZmlsZQ%3D%3D?line=1'>2</a> # query_dict[iteration] = dynamodb_chat_history(contactId)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X61sZmlsZQ%3D%3D?line=2'>3</a> query_dict[iteration] = query_dynamodb_table(contactId, 'ChatHistory', profile='default')
#       <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X61sZmlsZQ%3D%3D?line=3'>4</a> query_dict[iteration]
#
# c:\Users\silvh\OneDrive\lighthouse\portfolio-projects\GHL-chat\notebooks\2023-11-16 langchain chat message history.ipynb Cell 24 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X61sZmlsZQ%3D%3D?line=32'>33</a>     KeyConditionExpression = Key(partition_key).eq(partition_key_value)
#      <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X61sZmlsZQ%3D%3D?line=33'>34</a> print(f'KeyConditionExpression: {KeyConditionExpression}')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X61sZmlsZQ%3D%3D?line=34'>35</a> response = table.query(
#      <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X61sZmlsZQ%3D%3D?line=35'>36</a>     KeyConditionExpression=KeyConditionExpression,
#      <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X61sZmlsZQ%3D%3D?line=36'>37</a> )
#      <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X61sZmlsZQ%3D%3D?line=37'>38</a> return response
#
# File c:\Users\silvh\.conda\envs\projects\Lib\site-packages\boto3\resources\factory.py:580, in ResourceFactory._create_action.<locals>.do_action(self, *args, **kwargs)
#     579 def do_action(self, *args, **kwargs):
# --> 580     response = action(self, *args, **kwargs)
#     582     if hasattr(self, 'load'):
#     583         # Clear cached data. It will be reloaded the next
#     584         # time that an attribute is accessed.
#     585         # TODO: Make this configurable in the future?
#     586         self.meta.data = None
#
# File c:\Users\silvh\.conda\envs\projects\Lib\site-packages\boto3\resources\action.py:88, in ServiceAction.__call__(self, parent, *args, **kwargs)
#      79 params.update(kwargs)
#      81 logger.debug(
#      82     'Calling %s:%s with %r',
#      83     parent.meta.service_name,
#      84     operation_name,
#      85     params,
#      86 )
# ---> 88 response = getattr(parent.meta.client, operation_name)(*args, **params)
#      90 logger.debug('Response: %r', response)
#      92 return self._response_handler(parent, params, response)
#
# File c:\Users\silvh\.conda\envs\projects\Lib\site-packages\botocore\client.py:535, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     531     raise TypeError(
#     532         f"{py_operation_name}() only accepts keyword arguments."
#     533     )
#     534 # The "self" in this scope is referring to the BaseClient.
# --> 535 return self._make_api_call(operation_name, kwargs)
#
# File c:\Users\silvh\.conda\envs\projects\Lib\site-packages\botocore\client.py:980, in BaseClient._make_api_call(self, operation_name, api_params)
#     978     error_code = parsed_response.get("Error", {}).get("Code")
#     979     error_class = self.exceptions.from_code(error_code)
# --> 980     raise error_class(parsed_response, operation_name)
#     981 else:
#     982     return parsed_response
#
# ResourceNotFoundException: An error occurred (ResourceNotFoundException) when calling the Query operation: Requested resource not found

# %%
iteration = 1.252
# query_dict[iteration] = dynamodb_chat_history(contactId)
query_dict[iteration] = query_dynamodb_table(contactId, 'ChatHistory', profile='mcgill2')
query_dict[iteration]
# Out:
# KeyConditionExpression: <boto3.dynamodb.conditions.Equals object at 0x000002309CA9EBD0>
# ---------------------------------------------------------------------------
# ResourceNotFoundException                 Traceback (most recent call last)
# c:\Users\silvh\OneDrive\lighthouse\portfolio-projects\GHL-chat\notebooks\2023-11-16 langchain chat message history.ipynb Cell 25 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X62sZmlsZQ%3D%3D?line=0'>1</a> iteration = 1.252
#       <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X62sZmlsZQ%3D%3D?line=1'>2</a> # query_dict[iteration] = dynamodb_chat_history(contactId)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X62sZmlsZQ%3D%3D?line=2'>3</a> query_dict[iteration] = query_dynamodb_table(contactId, 'ChatHistory', profile='mcgill2')
#       <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X62sZmlsZQ%3D%3D?line=3'>4</a> query_dict[iteration]
#
# c:\Users\silvh\OneDrive\lighthouse\portfolio-projects\GHL-chat\notebooks\2023-11-16 langchain chat message history.ipynb Cell 25 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X62sZmlsZQ%3D%3D?line=32'>33</a>     KeyConditionExpression = Key(partition_key).eq(partition_key_value)
#      <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X62sZmlsZQ%3D%3D?line=33'>34</a> print(f'KeyConditionExpression: {KeyConditionExpression}')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X62sZmlsZQ%3D%3D?line=34'>35</a> response = table.query(
#      <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X62sZmlsZQ%3D%3D?line=35'>36</a>     KeyConditionExpression=KeyConditionExpression,
#      <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X62sZmlsZQ%3D%3D?line=36'>37</a> )
#      <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#X62sZmlsZQ%3D%3D?line=37'>38</a> return response
#
# File c:\Users\silvh\.conda\envs\projects\Lib\site-packages\boto3\resources\factory.py:580, in ResourceFactory._create_action.<locals>.do_action(self, *args, **kwargs)
#     579 def do_action(self, *args, **kwargs):
# --> 580     response = action(self, *args, **kwargs)
#     582     if hasattr(self, 'load'):
#     583         # Clear cached data. It will be reloaded the next
#     584         # time that an attribute is accessed.
#     585         # TODO: Make this configurable in the future?
#     586         self.meta.data = None
#
# File c:\Users\silvh\.conda\envs\projects\Lib\site-packages\boto3\resources\action.py:88, in ServiceAction.__call__(self, parent, *args, **kwargs)
#      79 params.update(kwargs)
#      81 logger.debug(
#      82     'Calling %s:%s with %r',
#      83     parent.meta.service_name,
#      84     operation_name,
#      85     params,
#      86 )
# ---> 88 response = getattr(parent.meta.client, operation_name)(*args, **params)
#      90 logger.debug('Response: %r', response)
#      92 return self._response_handler(parent, params, response)
#
# File c:\Users\silvh\.conda\envs\projects\Lib\site-packages\botocore\client.py:535, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     531     raise TypeError(
#     532         f"{py_operation_name}() only accepts keyword arguments."
#     533     )
#     534 # The "self" in this scope is referring to the BaseClient.
# --> 535 return self._make_api_call(operation_name, kwargs)
#
# File c:\Users\silvh\.conda\envs\projects\Lib\site-packages\botocore\client.py:980, in BaseClient._make_api_call(self, operation_name, api_params)
#     978     error_code = parsed_response.get("Error", {}).get("Code")
#     979     error_class = self.exceptions.from_code(error_code)
# --> 980     raise error_class(parsed_response, operation_name)
#     981 else:
#     982     return parsed_response
#
# ResourceNotFoundException: An error occurred (ResourceNotFoundException) when calling the Query operation: Requested resource not found

# %% [markdown]
# ### This one works after I delete the table in the original AWS account; likely the issue was from identical table names as both accounts are in the same organization

# %%
iteration = 1.251
# query_dict[iteration] = dynamodb_chat_history(contactId)
query_dict[iteration] = query_dynamodb_table(contactId)
query_dict[iteration]

# %% [markdown]
# ## 1.6 Update credentials file so mcgill account is default

# %%
import boto3
from boto3.dynamodb.conditions import Key
from langchain.memory.chat_message_histories import DynamoDBChatMessageHistory
from langchain.memory import ConversationBufferMemory

def query_dynamodb_table(
    partition_key_value, table_name='SessionTable', sort_key_value='', partition_key='SessionId', sort_key=None, 
    profile='mcgill_credentials', region_name="us-west-2"
    ):
    """
    Query a Dynamodb table based on both the partition key and sort key.
    Parameters:
        table_name (str): The name of the DynamoDB table.
        partition_key_value (str): The value of the partition key.
        sort_key_value (str): The value of the sort key.
        partition_key (str): The name of the partition key.
        sort_key (str): The name of the sort key.
        region_name (str): The name of the AWS region.

    Returns:
        dict: The results of the query. The 'Items' key contains the table record.       
    From 2023-10-22 notebook.
    """
    if profile:
        session = boto3.Session(profile_name=profile)
        dynamodb = session.resource('dynamodb', region_name=region_name)
    else:
        dynamodb = boto3.resource('dynamodb', region_name=region_name)
    table = dynamodb.Table(table_name)
    if sort_key:
        KeyConditionExpression = Key(partition_key).eq(partition_key_value) & Key(sort_key).eq(sort_key_value)
    else:
        KeyConditionExpression = Key(partition_key).eq(partition_key_value)
    print(f'KeyConditionExpression: {KeyConditionExpression}')
    response = table.query(
        KeyConditionExpression=KeyConditionExpression,
    )
    return response

def dynamodb_chat_history(contactId):
    message_history = DynamoDBChatMessageHistory(
        table_name="SessionTable", session_id=contactId,
        key={
            "SessionId": contactId,
            "type": 'ChatHistory',
            }
        )
    return message_history.messages

iteration = 1.25
query_dict[iteration] = dynamodb_chat_history(contactId)
# query_dict[iteration] = query_dynamodb_table(contactId, 'ChatHistory')
query_dict[iteration]
# Out:
# [AIMessage(content='Hi, Silvia'),
#  AIMessage(content='hi from ghl'),
#  AIMessage(content='Hi, Silvia!')]

# %% [markdown]
# # S3

# %%
s3 = boto3.client('s3')
response = s3.get_object(Bucket='ownitfit-silvhua', Key='auth_token_response.json')
response

# %%
token = response['Body']
token

# %%
response['Body'].read().decode('utf-8')
# Out:
# ''

# %% [markdown]
# ## 2.1 Refresh token

# %%
import requests
from urllib.parse import urlencode
def refresh_token():
    """
    Refreshes the authentication token. 

    This function does the following:
    1. Reads the application configuration from a local file.
    2. Attempts to load the authentication tokens from a local file.
    3. If local file is not found, it retrieves the tokens from an S3 bucket.
    4. Checks if the 'SamLab' token is present in the loaded tokens. If not, it returns an error.
    5. Prepares data for the token refresh request, including client_id, client_secret, grant_type, refresh_token, user_type, and redirect_uri from the application configuration and SamLab token.
    6. Sends a POST request to the Lead Connector API to refresh the token.
    7. If the token refresh request is successful, it updates the 'SamLab' token in the loaded tokens with the response and tries to save it to a local file.
    8. If local save fails, it tries to save the tokens to the same S3 bucket.
    9. If S3 save also fails, it prints the error details.
    10. Returns the response of the token refresh request.

    Returns:
        dict: A dictionary with 'statusCode', 'body', and optionally 'response' keys. 'statusCode' is 200 if the token refresh request is successful, and 500 otherwise. 'body' contains the response of the token refresh request if it is successful, and an error message otherwise. 'response' is present only if the token refresh request fails, and contains the response of the failed request.
    """
    token_file_path = '../src/private'
    filename = 'auth_token_response.json'

    with open(f'{token_file_path}/config.json') as config_file:
        appConfig = json.load(config_file)
    try:
        with open(f'{token_file_path}/{filename}', 'r') as token_file:
            tokens = json.load(token_file)
    except:
        # Load JSON from S3
        s3 = boto3.client('s3')
        response = s3.get_object(Bucket='ownitfit-silvhua', Key=filename)
        tokens = json.loads(response['Body'].read().decode('utf-8'))
    if 'SamLab' in tokens:
        sam_lab_token = tokens['SamLab']
    else:
        return {
            'statusCode': 500,
            'body': json.dumps({"error": "SamLab token not found in token_file."})
        }

    data = {
        'client_id': appConfig["clientId"],
        'client_secret': appConfig["clientSecret"],
        'grant_type': 'refresh_token',
        'refresh_token': sam_lab_token["refresh_token"],
        'user_type': 'Location',
        # 'redirect_uri': 'https://6r8pb7q836.execute-api.us-west-2.amazonaws.com/oauth/callback',
        'redirect_uri': 'http://localhost:3000/oauth/callback'
    }

    headers = {
        'Accept': 'application/json',
        'Content-Type': 'application/x-www-form-urlencoded'
    }

    response = requests.post('https://services.leadconnectorhq.com/oauth/token', data=urlencode(data), headers=headers)

    if response.status_code == 200:
        tokens['SamLab'] = response.json()
        try:
            with open(f'{token_file_path}/{filename}', 'w') as token_file:
                json.dump(tokens, token_file)
        except:
            try:
                # Save tokens to S3
                s3 = boto3.client('s3')
                s3.put_object(
                    Body=json.dumps(tokens), 
                    Bucket='ownitfit-silvhua', Key=filename
                    )
            except Exception as error:
                exc_type, exc_obj, tb = sys.exc_info()
                f = tb.tb_frame
                lineno = tb.tb_lineno
                filename = f.f_code.co_filename
                print(f"Unable to save tokens to S3. Error in line {lineno} of {filename}: {str(error)}")
        return {
            'statusCode': 200,
            'body': json.dumps(response.json())
        }
    else:
        return {
            'statusCode': 500,
            'body': json.dumps({"error": f"Failed to fetch access token: {response.reason}",}),
            'response': json.dumps(response.json())
        }
iteration = 2.1
query_dict[iteration] = refresh_token()

# %%
query_dict[iteration]

# %% [markdown]
# ## 2.2

# %%
import requests
from datetime import datetime
import json
import sys
from urllib.parse import urlencode
import boto3

def refresh_token():
    """
    Refreshes the authentication token. 

    This function does the following:
    1. Reads the application configuration from a local file.
    2. Attempts to load the authentication tokens from a local file.
    3. If local file is not found, it retrieves the tokens from an S3 bucket.
    4. Checks if the 'SamLab' token is present in the loaded tokens. If not, it returns an error.
    5. Prepares data for the token refresh request, including client_id, client_secret, grant_type, refresh_token, user_type, and redirect_uri from the application configuration and SamLab token.
    6. Sends a POST request to the Lead Connector API to refresh the token.
    7. If the token refresh request is successful, it updates the 'SamLab' token in the loaded tokens with the response and tries to save it to a local file.
    8. If local save fails, it tries to save the tokens to the same S3 bucket.
    9. If S3 save also fails, it prints the error details.
    10. Returns the response of the token refresh request.

    Returns:
        dict: A dictionary with 'statusCode', 'body', and optionally 'response' keys. 'statusCode' is 200 if the token refresh request is successful, and 500 otherwise. 'body' contains the response of the token refresh request if it is successful, and an error message otherwise. 'response' is present only if the token refresh request fails, and contains the response of the failed request.
    """
    token_file_path = '../src/private'
    filename = 'auth_token_response.json'

    with open(f'{token_file_path}/config.json') as config_file:
        appConfig = json.load(config_file)
    try:
        with open(f'{token_file_path}/{filename}', 'r') as token_file:
            tokens = json.load(token_file)
    except:
        # Load JSON from S3
        s3 = boto3.client('s3')
        response = s3.get_object(Bucket='ownitfit-silvhua', Key=filename)
        tokens = json.loads(response['Body'].read().decode('utf-8'))
    if 'SamLab' in tokens:
        sam_lab_token = tokens['SamLab']
    else:
        return {
            'statusCode': 500,
            'body': json.dumps({"error": "SamLab token not found in token_file."})
        }

    data = {
        'client_id': appConfig["clientId"],
        'client_secret': appConfig["clientSecret"],
        'grant_type': 'refresh_token',
        'refresh_token': sam_lab_token["refresh_token"],
        'user_type': 'Location',
        # 'redirect_uri': 'https://6r8pb7q836.execute-api.us-west-2.amazonaws.com/oauth/callback',
        'redirect_uri': 'http://localhost:3000/oauth/callback'
    }

    headers = {
        'Accept': 'application/json',
        'Content-Type': 'application/x-www-form-urlencoded'
    }

    response = requests.post('https://services.leadconnectorhq.com/oauth/token', data=urlencode(data), headers=headers)

    if response.status_code == 200:
        tokens['SamLab'] = response.json()
        try:
            with open(f'{token_file_path}/{filename}', 'w') as token_file:
                json.dump(tokens, token_file)
        except:
            try:
                # Save tokens to S3
                s3 = boto3.client('s3')
                s3.put_object(
                    Body=json.dumps(tokens), 
                    Bucket='ownitfit-silvhua', Key=filename
                    )
            except Exception as error:
                exc_type, exc_obj, tb = sys.exc_info()
                f = tb.tb_frame
                lineno = tb.tb_lineno
                filename = f.f_code.co_filename
                print(f"Unable to save tokens to S3. Error in line {lineno} of {filename}: {str(error)}")
        return {
            'statusCode': 200,
            'body': json.dumps(response.json())
        }
    else:
        return {
            'statusCode': 500,
            'body': json.dumps({"error": f"Failed to fetch access token: {response.reason}",}),
            'response': json.dumps(response.json())
        }
iteration = 2.2
query_dict[iteration] = refresh_token()
query_dict[iteration]

# %% [markdown]
# ## 2.3

# %%
import requests
from datetime import datetime
import json
import sys
from urllib.parse import urlencode
import boto3

def refresh_token():
    """
    Refreshes the authentication token. 

    This function does the following:
    1. Reads the application configuration from a local file.
    2. Attempts to load the authentication tokens from a local file.
    3. If local file is not found, it retrieves the tokens from an S3 bucket.
    4. Checks if the 'SamLab' token is present in the loaded tokens. If not, it returns an error.
    5. Prepares data for the token refresh request, including client_id, client_secret, grant_type, refresh_token, user_type, and redirect_uri from the application configuration and SamLab token.
    6. Sends a POST request to the Lead Connector API to refresh the token.
    7. If the token refresh request is successful, it updates the 'SamLab' token in the loaded tokens with the response and tries to save it to a local file.
    8. If local save fails, it tries to save the tokens to the same S3 bucket.
    9. If S3 save also fails, it prints the error details.
    10. Returns the response of the token refresh request.

    Returns:
        dict: A dictionary with 'statusCode', 'body', and optionally 'response' keys. 'statusCode' is 200 if the token refresh request is successful, and 500 otherwise. 'body' contains the response of the token refresh request if it is successful, and an error message otherwise. 'response' is present only if the token refresh request fails, and contains the response of the failed request.
    """
    token_file_path = '../src/private'
    filename = 'auth_token_response.json'

    with open(f'{token_file_path}/config.json') as config_file:
        appConfig = json.load(config_file)
    token_file_path = 'hello'
    try:
        with open(f'{token_file_path}/{filename}', 'r') as token_file:
            tokens = json.load(token_file)
    except:
        # Load JSON from S3
        s3 = boto3.client('s3')
        response = s3.get_object(Bucket='ownitfit-silvhua', Key=filename)
        tokens = json.loads(response['Body'].read().decode('utf-8'))
    if 'SamLab' in tokens:
        sam_lab_token = tokens['SamLab']
    else:
        return {
            'statusCode': 500,
            'body': json.dumps({"error": "SamLab token not found in token_file."})
        }

    data = {
        'client_id': appConfig["clientId"],
        'client_secret': appConfig["clientSecret"],
        'grant_type': 'refresh_token',
        'refresh_token': sam_lab_token["refresh_token"],
        'user_type': 'Location',
        'redirect_uri': 'http://localhost:3000/oauth/callback'
    }

    headers = {
        'Accept': 'application/json',
        'Content-Type': 'application/x-www-form-urlencoded'
    }

    response = requests.post('https://services.leadconnectorhq.com/oauth/token', data=urlencode(data), headers=headers)

    if response.status_code == 200:
        tokens['SamLab'] = response.json()
        try:
            with open(f'{token_file_path}/{filename}', 'w') as token_file:
                json.dump(tokens, token_file)
            print(f'Tokens saved to {token_file_path}/{filename}')
        except:
            try:
                # Save tokens to S3
                s3 = boto3.client('s3')
                s3.put_object(
                    Body=json.dumps(tokens), 
                    Bucket='ownitfit-silvhua', Key=filename
                    )
                print(f'Tokens saved to S3 bucket ownitfit-silvhua/{filename}')
            except Exception as error:
                exc_type, exc_obj, tb = sys.exc_info()
                f = tb.tb_frame
                lineno = tb.tb_lineno
                filename = f.f_code.co_filename
                print(f"Unable to save tokens to S3. Error in line {lineno} of {filename}: {str(error)}")
        return {
            'statusCode': 200,
            'body': json.dumps(response.json())
        }
    else:
        return {
            'statusCode': 500,
            'body': json.dumps({"error": f"Failed to fetch access token: {response.reason}",}),
            'response': json.dumps(response.json())
        }
iteration = 2.3
query_dict[iteration] = refresh_token()
query_dict[iteration]

# %% [markdown]
# # 3 ghl_request

# %%
import requests
from datetime import datetime
import json
import sys
from urllib.parse import urlencode
import boto3

def ghl_request(contactId, endpoint='createTask', text=None, payload=None, location='SamLab'):
    """
    Send a message to a contact in GoHighLevel or retrieve email history.

    Parameters:
    - contactId (str): Contact ID.
    - endpoint (str): API endpoint. Valid values are 'createTask', 'createNote', 'send_message', and 'getEmailHistory'.
    - payload (dict): Dictionary containing the payload for the request.
    - params_dict (dict): Dictionary containing additional parameters for the request.
    - location (str): Location value for retrieving the authentication token.

    Example payload for sendMessage endpoint:
        
            payload = {
                "type": "Email",
                "message": f"Hi, me. This is a test message from the GHL API using Python at {timestamp} Pacific time",
                "subject": "Testing GHL API with Python threadId",
                "emailFrom": "Brian Quinlan <brian@ownitfit.com.au>",
                "threadId": 'Y0ecBIIPiHa7bpZr616G'
            }

    Returns:
    - response_dict (dict): Dictionary containing the response from the API.
    """
    url_root = 'https://services.leadconnectorhq.com/'
    if payload:
        print(f'input payload: {payload}')
    try:
        if endpoint == 'createNote':
            endpoint_url = f'contacts/{contactId}/notes'
            request_type = 'POST'
            if payload == None:
                payload = {}
                payload['body'] = (f"Reply to SMS (contactID {contactId}) {datetime.utcnow().strftime('%Y-%m-%dT%H:%M:%SZ')}" if text==None else text)
                payload['userId'] = contactId
        elif endpoint == 'createTask':
            endpoint_url = f'contacts/{contactId}/tasks'
            request_type = 'POST'
            if payload == None:
                payload = {}
                payload['title'] = f'Send message to contact {contactId}'
                payload['body'] = text if text else f"Test task via GHL API at {datetime.utcnow().strftime('%Y-%m-%dT%H:%M:%SZ')} Pacific time"
            payload['dueDate'] = payload.get('dueDate', datetime.utcnow().strftime('%Y-%m-%dT%H:%M:%SZ'))
            payload['completed'] = False
        elif endpoint == 'sendMessage':
            endpoint_url = f'conversations/messages'
            request_type = 'POST'
            payload["contactId"] = contactId
            if payload['type'] == 'Email':
                payload['html'] = payload['message']
        elif endpoint == 'getEmailHistory':
            endpoint_url = f'conversations/search?contactId={contactId}'
            request_type = 'GET'
            payload = None
        else:
            raise ValueError("Invalid endpoint value. Valid values are 'createTask', 'createNote', 'sendMessage', and 'getEmailHistory'.")

        url = f'{url_root}{endpoint_url}'
        try:
            with open('private/auth_token_response.json') as token_file:
                token = json.load(token_file)[location]
        except:
            try:
                s3 = boto3.client('s3')
                response = s3.get_object(Bucket='ownitfit-silvhua', Key='auth_token_response.json')
                print(f'Token reponse: {response}')
                token = response['Body'].read().decode('utf-8')[location]
            except Exception as error:
                exc_type, exc_obj, tb = sys.exc_info()
                f = tb.tb_frame
                lineno = tb.tb_lineno
                filename = f.f_code.co_filename
                print(f'Error in line {lineno} of {filename}: {str(error)}')
                return None

        headers = {
            "Authorization": f"Bearer {token['access_token']}",
            "Version": "2021-04-15",
            "Content-Type": "application/json",
            "Accept": "application/json"
        }


        if request_type == 'POST':
            response = requests.post(
                url, headers=headers, 
                json=payload if payload else None
            )
        elif request_type == 'GET':
            response = requests.get(
                url, headers=headers, 
                json=payload if payload else None
            )
        else:
            raise ValueError("Invalid request type. Valid values are 'POST' and 'GET'.")

        print(f'Status code {response.status_code}: {response.reason}')
        data = response.json()
        data['status_code'] = response.status_code
        data['response_reason'] = response.reason
        try:
            if endpoint == 'getEmailHistory':
                email_timestamp = data['conversations'][0]['dateUpdated']/1000
                utc_time = datetime.utcfromtimestamp(email_timestamp)
                pacific_time = utc_time.replace(tzinfo=pytz.utc).astimezone(pytz.timezone('US/Pacific'))
                email_timestamp_str = pacific_time.strftime('%Y-%m-%d %H:%M:%S')

                print(f'Last email sent: {email_timestamp_str} Pacific time')
                data['emailTimestamp_pacific'] = email_timestamp_str
        except Exception as error:
            exc_type, exc_obj, tb = sys.exc_info()
            f = tb.tb_frame
            lineno = tb.tb_lineno
            filename = f.f_code.co_filename
            print(f'Error in line {lineno} of {filename}: {str(error)}')
            return '[Chatbot response]'
        return data
    except Exception as error:
        exc_type, exc_obj, tb = sys.exc_info()
        f = tb.tb_frame
        lineno = tb.tb_lineno
        filename = f.f_code.co_filename
        print(f'Error in line {lineno} of {filename}: {str(error)}')
        return '[Chatbot response]'

iteration = 3
location = 'SamLab'
business_dict = {
    'SAM_Lab': (
        'SAM_Lab.txt', # business-specific system message
        'SAM_Lab_examples.txt', # Examples 
        'SAM_Lab_doc.md' # RAG doc
        )
}
text = 'When are you open on Sunday'
query_dict[iteration] = ghl_request(
                contactId=contactId, 
                text=text,
                endpoint='createTask', 
                payload=business_dict, 
                location=location
            )

query_dict[iteration]

# %% [markdown]
# ## 3.1

# %%
import requests
from datetime import datetime
import json
import sys
from urllib.parse import urlencode
import boto3

def ghl_request(contactId, endpoint='createTask', text=None, payload=None, location='SamLab'):
    """
    Send a message to a contact in GoHighLevel or retrieve email history.

    Parameters:
    - contactId (str): Contact ID.
    - endpoint (str): API endpoint. Valid values are 'createTask', 'createNote', 'send_message', and 'getEmailHistory'.
    - payload (dict): Dictionary containing the payload for the request.
    - params_dict (dict): Dictionary containing additional parameters for the request.
    - location (str): Location value for retrieving the authentication token.

    Example payload for sendMessage endpoint:
        
            payload = {
                "type": "Email",
                "message": f"Hi, me. This is a test message from the GHL API using Python at {timestamp} Pacific time",
                "subject": "Testing GHL API with Python threadId",
                "emailFrom": "Brian Quinlan <brian@ownitfit.com.au>",
                "threadId": 'Y0ecBIIPiHa7bpZr616G'
            }

    Returns:
    - response_dict (dict): Dictionary containing the response from the API.
    """
    url_root = 'https://services.leadconnectorhq.com/'
    if payload:
        print(f'input payload: {payload}')
    if endpoint == 'createNote':
        endpoint_url = f'contacts/{contactId}/notes'
        request_type = 'POST'
        if payload == None:
            payload = {}
            payload['body'] = (f"Reply to SMS (contactID {contactId}) {datetime.utcnow().strftime('%Y-%m-%dT%H:%M:%SZ')}" if text==None else text)
            payload['userId'] = contactId
    elif endpoint == 'createTask':
        endpoint_url = f'contacts/{contactId}/tasks'
        request_type = 'POST'
        if payload == None:
            payload = {}
            payload['title'] = f'Send message to contact {contactId}'
            payload['body'] = text if text else f"Test task via GHL API at {datetime.utcnow().strftime('%Y-%m-%dT%H:%M:%SZ')} Pacific time"
        payload['dueDate'] = payload.get('dueDate', datetime.utcnow().strftime('%Y-%m-%dT%H:%M:%SZ'))
        payload['completed'] = False
    elif endpoint == 'sendMessage':
        endpoint_url = f'conversations/messages'
        request_type = 'POST'
        payload["contactId"] = contactId
        if payload['type'] == 'Email':
            payload['html'] = payload['message']
    elif endpoint == 'getEmailHistory':
        endpoint_url = f'conversations/search?contactId={contactId}'
        request_type = 'GET'
        payload = None
    else:
        raise ValueError("Invalid endpoint value. Valid values are 'createTask', 'createNote', 'sendMessage', and 'getEmailHistory'.")

    url = f'{url_root}{endpoint_url}'
    try:
        with open('private/auth_token_response.json') as token_file:
            token = json.load(token_file)[location]
    except:
        try:
            s3 = boto3.client('s3')
            response = s3.get_object(Bucket='ownitfit-silvhua', Key='auth_token_response.json')
            print(f'Token reponse: {response}')
            token = response['Body'].read().decode('utf-8')[location]
        except Exception as error:
            exc_type, exc_obj, tb = sys.exc_info()
            f = tb.tb_frame
            lineno = tb.tb_lineno
            filename = f.f_code.co_filename
            print(f'Error in line {lineno} of {filename}: {str(error)}')
            return response['Body'].read().decode('utf-8')
            return None

    #     headers = {
    #         "Authorization": f"Bearer {token['access_token']}",
    #         "Version": "2021-04-15",
    #         "Content-Type": "application/json",
    #         "Accept": "application/json"
    #     }


    #     if request_type == 'POST':
    #         response = requests.post(
    #             url, headers=headers, 
    #             json=payload if payload else None
    #         )
    #     elif request_type == 'GET':
    #         response = requests.get(
    #             url, headers=headers, 
    #             json=payload if payload else None
    #         )
    #     else:
    #         raise ValueError("Invalid request type. Valid values are 'POST' and 'GET'.")

    #     print(f'Status code {response.status_code}: {response.reason}')
    #     data = response.json()
    #     data['status_code'] = response.status_code
    #     data['response_reason'] = response.reason
    #     try:
    #         if endpoint == 'getEmailHistory':
    #             email_timestamp = data['conversations'][0]['dateUpdated']/1000
    #             utc_time = datetime.utcfromtimestamp(email_timestamp)
    #             pacific_time = utc_time.replace(tzinfo=pytz.utc).astimezone(pytz.timezone('US/Pacific'))
    #             email_timestamp_str = pacific_time.strftime('%Y-%m-%d %H:%M:%S')

    #             print(f'Last email sent: {email_timestamp_str} Pacific time')
    #             data['emailTimestamp_pacific'] = email_timestamp_str
    #     except Exception as error:
    #         exc_type, exc_obj, tb = sys.exc_info()
    #         f = tb.tb_frame
    #         lineno = tb.tb_lineno
    #         filename = f.f_code.co_filename
    #         print(f'Error in line {lineno} of {filename}: {str(error)}')
    #         return '[Chatbot response]'
    #     return data
    # except Exception as error:
    #     exc_type, exc_obj, tb = sys.exc_info()
    #     f = tb.tb_frame
    #     lineno = tb.tb_lineno
    #     filename = f.f_code.co_filename
    #     print(f'Error in line {lineno} of {filename}: {str(error)}')
    #     return '[Chatbot response]'

iteration = 3.1
location = 'SamLab'
business_dict = {
    'SAM_Lab': (
        'SAM_Lab.txt', # business-specific system message
        'SAM_Lab_examples.txt', # Examples 
        'SAM_Lab_doc.md' # RAG doc
        )
}
text = 'When are you open on Sunday'
query_dict[iteration] = ghl_request(
                contactId=contactId, 
                text=text,
                endpoint='createTask', 
                payload=business_dict, 
                location=location
            )

query_dict[iteration]

# %%
print(query_dict[iteration])

# %% [markdown]
# ## 3.2

# %%
import requests
from datetime import datetime
import json
import sys
from urllib.parse import urlencode
import boto3

def ghl_request(contactId, endpoint='createTask', text=None, payload=None, location='SamLab'):
    """
    Send a message to a contact in GoHighLevel or retrieve email history.

    Parameters:
    - contactId (str): Contact ID.
    - endpoint (str): API endpoint. Valid values are 'createTask', 'createNote', 'send_message', and 'getEmailHistory'.
    - payload (dict): Dictionary containing the payload for the request.
    - params_dict (dict): Dictionary containing additional parameters for the request.
    - location (str): Location value for retrieving the authentication token.

    Example payload for sendMessage endpoint:
        
            payload = {
                "type": "Email",
                "message": f"Hi, me. This is a test message from the GHL API using Python at {timestamp} Pacific time",
                "subject": "Testing GHL API with Python threadId",
                "emailFrom": "Brian Quinlan <brian@ownitfit.com.au>",
                "threadId": 'Y0ecBIIPiHa7bpZr616G'
            }

    Returns:
    - response_dict (dict): Dictionary containing the response from the API.
    """
    url_root = 'https://services.leadconnectorhq.com/'
    if payload:
        print(f'input payload: {payload}')
    if endpoint == 'createNote':
        endpoint_url = f'contacts/{contactId}/notes'
        request_type = 'POST'
        if payload == None:
            payload = {}
            payload['body'] = (f"Reply to SMS (contactID {contactId}) {datetime.utcnow().strftime('%Y-%m-%dT%H:%M:%SZ')}" if text==None else text)
            payload['userId'] = contactId
    elif endpoint == 'createTask':
        endpoint_url = f'contacts/{contactId}/tasks'
        request_type = 'POST'
        if payload == None:
            payload = {}
            payload['title'] = f'Send message to contact {contactId}'
            payload['body'] = text if text else f"Test task via GHL API at {datetime.utcnow().strftime('%Y-%m-%dT%H:%M:%SZ')} Pacific time"
        payload['dueDate'] = payload.get('dueDate', datetime.utcnow().strftime('%Y-%m-%dT%H:%M:%SZ'))
        payload['completed'] = False
    elif endpoint == 'sendMessage':
        endpoint_url = f'conversations/messages'
        request_type = 'POST'
        payload["contactId"] = contactId
        if payload['type'] == 'Email':
            payload['html'] = payload['message']
    elif endpoint == 'getEmailHistory':
        endpoint_url = f'conversations/search?contactId={contactId}'
        request_type = 'GET'
        payload = None
    else:
        raise ValueError("Invalid endpoint value. Valid values are 'createTask', 'createNote', 'sendMessage', and 'getEmailHistory'.")

    url = f'{url_root}{endpoint_url}'
    try:
        with open('private/auth_token_response.json') as token_file:
            token = json.load(token_file)[location]
    except:
        try:
            s3 = boto3.client('s3')
            response = s3.get_object(Bucket='ownitfit-silvhua', Key='auth_token_response.json')
            print(f'Token reponse: {response}')
            token = response['Body'].read().decode('utf-8')[location]
        except Exception as error:
            exc_type, exc_obj, tb = sys.exc_info()
            f = tb.tb_frame
            lineno = tb.tb_lineno
            filename = f.f_code.co_filename
            print(f'Error in line {lineno} of {filename}: {str(error)}')
            return response['Body']
            return None

    #     headers = {
    #         "Authorization": f"Bearer {token['access_token']}",
    #         "Version": "2021-04-15",
    #         "Content-Type": "application/json",
    #         "Accept": "application/json"
    #     }


    #     if request_type == 'POST':
    #         response = requests.post(
    #             url, headers=headers, 
    #             json=payload if payload else None
    #         )
    #     elif request_type == 'GET':
    #         response = requests.get(
    #             url, headers=headers, 
    #             json=payload if payload else None
    #         )
    #     else:
    #         raise ValueError("Invalid request type. Valid values are 'POST' and 'GET'.")

    #     print(f'Status code {response.status_code}: {response.reason}')
    #     data = response.json()
    #     data['status_code'] = response.status_code
    #     data['response_reason'] = response.reason
    #     try:
    #         if endpoint == 'getEmailHistory':
    #             email_timestamp = data['conversations'][0]['dateUpdated']/1000
    #             utc_time = datetime.utcfromtimestamp(email_timestamp)
    #             pacific_time = utc_time.replace(tzinfo=pytz.utc).astimezone(pytz.timezone('US/Pacific'))
    #             email_timestamp_str = pacific_time.strftime('%Y-%m-%d %H:%M:%S')

    #             print(f'Last email sent: {email_timestamp_str} Pacific time')
    #             data['emailTimestamp_pacific'] = email_timestamp_str
    #     except Exception as error:
    #         exc_type, exc_obj, tb = sys.exc_info()
    #         f = tb.tb_frame
    #         lineno = tb.tb_lineno
    #         filename = f.f_code.co_filename
    #         print(f'Error in line {lineno} of {filename}: {str(error)}')
    #         return '[Chatbot response]'
    #     return data
    # except Exception as error:
    #     exc_type, exc_obj, tb = sys.exc_info()
    #     f = tb.tb_frame
    #     lineno = tb.tb_lineno
    #     filename = f.f_code.co_filename
    #     print(f'Error in line {lineno} of {filename}: {str(error)}')
    #     return '[Chatbot response]'

iteration = 3.2
location = 'SamLab'
business_dict = {
    'SAM_Lab': (
        'SAM_Lab.txt', # business-specific system message
        'SAM_Lab_examples.txt', # Examples 
        'SAM_Lab_doc.md' # RAG doc
        )
}
text = 'When are you open on Sunday'
query_dict[iteration] = ghl_request(
                contactId=contactId, 
                text=text,
                endpoint='createTask', 
                payload=business_dict, 
                location=location
            )

query_dict[iteration]

# %%
query_dict[iteration].read()
# Out:
# b''

# %%
json.loads(query_dict[3.2].read().decode('utf-8'))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# c:\Users\silvh\OneDrive\lighthouse\portfolio-projects\GHL-chat\notebooks\2023-11-16 langchain chat message history.ipynb Cell 49 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/silvh/OneDrive/lighthouse/portfolio-projects/GHL-chat/notebooks/2023-11-16%20langchain%20chat%20message%20history.ipynb#Y115sZmlsZQ%3D%3D?line=0'>1</a> json.loads(query_dict[3.2].read().decode('utf-8'))
#
# File c:\Users\silvh\.conda\envs\projects\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File c:\Users\silvh\.conda\envs\projects\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File c:\Users\silvh\.conda\envs\projects\Lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# ## 3.3

# %%
import requests
from datetime import datetime
import json
import sys
from urllib.parse import urlencode
import boto3

def ghl_request(contactId, endpoint='createTask', text=None, payload=None, location='SamLab'):
    """
    Send a message to a contact in GoHighLevel or retrieve email history.

    Parameters:
    - contactId (str): Contact ID.
    - endpoint (str): API endpoint. Valid values are 'createTask', 'createNote', 'send_message', and 'getEmailHistory'.
    - payload (dict): Dictionary containing the payload for the request.
    - params_dict (dict): Dictionary containing additional parameters for the request.
    - location (str): Location value for retrieving the authentication token.

    Example payload for sendMessage endpoint:
        
            payload = {
                "type": "Email",
                "message": f"Hi, me. This is a test message from the GHL API using Python at {timestamp} Pacific time",
                "subject": "Testing GHL API with Python threadId",
                "emailFrom": "Brian Quinlan <brian@ownitfit.com.au>",
                "threadId": 'Y0ecBIIPiHa7bpZr616G'
            }

    Returns:
    - response_dict (dict): Dictionary containing the response from the API.
    """
    url_root = 'https://services.leadconnectorhq.com/'
    if payload:
        print(f'input payload: {payload}')
    try:
        if endpoint == 'createNote':
            endpoint_url = f'contacts/{contactId}/notes'
            request_type = 'POST'
            if payload == None:
                payload = {}
                payload['body'] = (f"Reply to SMS (contactID {contactId}) {datetime.utcnow().strftime('%Y-%m-%dT%H:%M:%SZ')}" if text==None else text)
                payload['userId'] = contactId
        elif endpoint == 'createTask':
            endpoint_url = f'contacts/{contactId}/tasks'
            request_type = 'POST'
            if payload == None:
                payload = {}
                payload['title'] = f'Send message to contact {contactId}'
                payload['body'] = text if text else f"Test task via GHL API at {datetime.utcnow().strftime('%Y-%m-%dT%H:%M:%SZ')} Pacific time"
            payload['dueDate'] = payload.get('dueDate', datetime.utcnow().strftime('%Y-%m-%dT%H:%M:%SZ'))
            payload['completed'] = False
        elif endpoint == 'sendMessage':
            endpoint_url = f'conversations/messages'
            request_type = 'POST'
            payload["contactId"] = contactId
            if payload['type'] == 'Email':
                payload['html'] = payload['message']
        elif endpoint == 'getEmailHistory':
            endpoint_url = f'conversations/search?contactId={contactId}'
            request_type = 'GET'
            payload = None
        else:
            raise ValueError("Invalid endpoint value. Valid values are 'createTask', 'createNote', 'sendMessage', and 'getEmailHistory'.")

        url = f'{url_root}{endpoint_url}'
        try:
            with open('private/auth_token_response.json') as token_file:
                token = json.load(token_file)[location]
        except:
            try:
                s3 = boto3.client('s3')
                response = s3.get_object(Bucket='ownitfit-silvhua', Key='auth_token_response.json')
                print(f'Token reponse: {response}')
                token = json.loads(response['Body'].read().decode('utf-8'))[location]
            except Exception as error:
                exc_type, exc_obj, tb = sys.exc_info()
                f = tb.tb_frame
                lineno = tb.tb_lineno
                filename = f.f_code.co_filename
                print(f'Error in line {lineno} of {filename}: {str(error)}')
                return None

        headers = {
            "Authorization": f"Bearer {token['access_token']}",
            "Version": "2021-04-15",
            "Content-Type": "application/json",
            "Accept": "application/json"
        }


        if request_type == 'POST':
            response = requests.post(
                url, headers=headers, 
                json=payload if payload else None
            )
        elif request_type == 'GET':
            response = requests.get(
                url, headers=headers, 
                json=payload if payload else None
            )
        else:
            raise ValueError("Invalid request type. Valid values are 'POST' and 'GET'.")

        print(f'Status code {response.status_code}: {response.reason}')
        data = response.json()
        data['status_code'] = response.status_code
        data['response_reason'] = response.reason
        try:
            if endpoint == 'getEmailHistory':
                email_timestamp = data['conversations'][0]['dateUpdated']/1000
                utc_time = datetime.utcfromtimestamp(email_timestamp)
                pacific_time = utc_time.replace(tzinfo=pytz.utc).astimezone(pytz.timezone('US/Pacific'))
                email_timestamp_str = pacific_time.strftime('%Y-%m-%d %H:%M:%S')

                print(f'Last email sent: {email_timestamp_str} Pacific time')
                data['emailTimestamp_pacific'] = email_timestamp_str
        except Exception as error:
            exc_type, exc_obj, tb = sys.exc_info()
            f = tb.tb_frame
            lineno = tb.tb_lineno
            filename = f.f_code.co_filename
            print(f'Error in line {lineno} of {filename}: {str(error)}')
            return '[Chatbot response]'
        return data
    except Exception as error:
        exc_type, exc_obj, tb = sys.exc_info()
        f = tb.tb_frame
        lineno = tb.tb_lineno
        filename = f.f_code.co_filename
        print(f'Error in line {lineno} of {filename}: {str(error)}')
        return '[Chatbot response]'

iteration = 3.3
location = 'SamLab'
business_dict = {
    'SAM_Lab': (
        'SAM_Lab.txt', # business-specific system message
        'SAM_Lab_examples.txt', # Examples 
        'SAM_Lab_doc.md' # RAG doc
        )
}
text = 'When are you open on Sunday'
query_dict[iteration] = ghl_request(
                contactId=contactId, 
                text=text,
                endpoint='createTask', 
                payload=business_dict, 
                location=location
            )

query_dict[iteration]

# %% [markdown]
# ## 3.31

# %%
import requests
from datetime import datetime
import json
import sys
from urllib.parse import urlencode
import boto3

def ghl_request(contactId, endpoint='createTask', text=None, payload=None, location='SamLab'):
    """
    Send a message to a contact in GoHighLevel or retrieve email history.

    Parameters:
    - contactId (str): Contact ID.
    - endpoint (str): API endpoint. Valid values are 'createTask', 'createNote', 'send_message', and 'getEmailHistory'.
    - payload (dict): Dictionary containing the payload for the request.
    - params_dict (dict): Dictionary containing additional parameters for the request.
    - location (str): Location value for retrieving the authentication token.

    Example payload for sendMessage endpoint:
        
            payload = {
                "type": "Email",
                "message": f"Hi, me. This is a test message from the GHL API using Python at {timestamp} Pacific time",
                "subject": "Testing GHL API with Python threadId",
                "emailFrom": "Brian Quinlan <brian@ownitfit.com.au>",
                "threadId": 'Y0ecBIIPiHa7bpZr616G'
            }

    Returns:
    - response_dict (dict): Dictionary containing the response from the API.
    """
    url_root = 'https://services.leadconnectorhq.com/'
    if payload:
        print(f'input payload: {payload}')
    try:
        if endpoint == 'createNote':
            endpoint_url = f'contacts/{contactId}/notes'
            request_type = 'POST'
            if payload == None:
                payload = {}
                payload['body'] = (f"Reply to SMS (contactID {contactId}) {datetime.utcnow().strftime('%Y-%m-%dT%H:%M:%SZ')}" if text==None else text)
                payload['userId'] = contactId
        elif endpoint == 'createTask':
            endpoint_url = f'contacts/{contactId}/tasks'
            request_type = 'POST'
            if payload == None:
                payload = {}
                payload['title'] = f'Send message to contact {contactId}'
                payload['body'] = text if text else f"Test task via GHL API at {datetime.utcnow().strftime('%Y-%m-%dT%H:%M:%SZ')} Pacific time"
            payload['dueDate'] = payload.get('dueDate', datetime.utcnow().strftime('%Y-%m-%dT%H:%M:%SZ'))
            payload['completed'] = False
        elif endpoint == 'sendMessage':
            endpoint_url = f'conversations/messages'
            request_type = 'POST'
            payload["contactId"] = contactId
            if payload['type'] == 'Email':
                payload['html'] = payload['message']
        elif endpoint == 'getEmailHistory':
            endpoint_url = f'conversations/search?contactId={contactId}'
            request_type = 'GET'
            payload = None
        else:
            raise ValueError("Invalid endpoint value. Valid values are 'createTask', 'createNote', 'sendMessage', and 'getEmailHistory'.")

        url = f'{url_root}{endpoint_url}'
        try:
            with open('private/auth_token_response.json') as token_file:
                token = json.load(token_file)[location]
        except:
            try:
                s3 = boto3.client('s3')
                response = s3.get_object(Bucket='ownitfit-silvhua', Key='auth_token_response.json')
                print(f'Token reponse: {response}')
                token = json.loads(response['Body'].read().decode('utf-8'))
                # token = json.loads(response['Body'].read().decode('utf-8'))[location]
            except Exception as error:
                exc_type, exc_obj, tb = sys.exc_info()
                f = tb.tb_frame
                lineno = tb.tb_lineno
                filename = f.f_code.co_filename
                print(f'Error in line {lineno} of {filename}: {str(error)}')
                return None

        headers = {
            "Authorization": f"Bearer {token['access_token']}",
            "Version": "2021-04-15",
            "Content-Type": "application/json",
            "Accept": "application/json"
        }


        if request_type == 'POST':
            response = requests.post(
                url, headers=headers, 
                json=payload if payload else None
            )
        elif request_type == 'GET':
            response = requests.get(
                url, headers=headers, 
                json=payload if payload else None
            )
        else:
            raise ValueError("Invalid request type. Valid values are 'POST' and 'GET'.")

        print(f'Status code {response.status_code}: {response.reason}')
        data = response.json()
        data['status_code'] = response.status_code
        data['response_reason'] = response.reason
        try:
            if endpoint == 'getEmailHistory':
                email_timestamp = data['conversations'][0]['dateUpdated']/1000
                utc_time = datetime.utcfromtimestamp(email_timestamp)
                pacific_time = utc_time.replace(tzinfo=pytz.utc).astimezone(pytz.timezone('US/Pacific'))
                email_timestamp_str = pacific_time.strftime('%Y-%m-%d %H:%M:%S')

                print(f'Last email sent: {email_timestamp_str} Pacific time')
                data['emailTimestamp_pacific'] = email_timestamp_str
        except Exception as error:
            exc_type, exc_obj, tb = sys.exc_info()
            f = tb.tb_frame
            lineno = tb.tb_lineno
            filename = f.f_code.co_filename
            print(f'Error in line {lineno} of {filename}: {str(error)}')
            return '[Chatbot response]'
        return data
    except Exception as error:
        exc_type, exc_obj, tb = sys.exc_info()
        f = tb.tb_frame
        lineno = tb.tb_lineno
        filename = f.f_code.co_filename
        print(f'Error in line {lineno} of {filename}: {str(error)}')
        return '[Chatbot response]'

iteration = 3.31
location = 'SamLab'
business_dict = {
    'SAM_Lab': (
        'SAM_Lab.txt', # business-specific system message
        'SAM_Lab_examples.txt', # Examples 
        'SAM_Lab_doc.md' # RAG doc
        )
}
text = 'When are you open on Sunday'
query_dict[iteration] = ghl_request(
                contactId=contactId, 
                text=text,
                endpoint='createTask', 
                payload=business_dict, 
                location=location
            )

query_dict[iteration]

# %%
query_dict[iteration]
# Out:
# '[Chatbot response]'

# %% [markdown]
# ## 3.4

# %%
import requests
from datetime import datetime
import json
import sys
from urllib.parse import urlencode
import boto3

def ghl_request(contactId, endpoint='createTask', text=None, payload=None, location='SamLab'):
    """
    Send a message to a contact in GoHighLevel or retrieve email history.

    Parameters:
    - contactId (str): Contact ID.
    - endpoint (str): API endpoint. Valid values are 'createTask', 'createNote', 'send_message', and 'getEmailHistory'.
    - payload (dict): Dictionary containing the payload for the request.
    - params_dict (dict): Dictionary containing additional parameters for the request.
    - location (str): Location value for retrieving the authentication token.

    Example payload for sendMessage endpoint:
        
            payload = {
                "type": "Email",
                "message": f"Hi, me. This is a test message from the GHL API using Python at {timestamp} Pacific time",
                "subject": "Testing GHL API with Python threadId",
                "emailFrom": "Brian Quinlan <brian@ownitfit.com.au>",
                "threadId": 'Y0ecBIIPiHa7bpZr616G'
            }

    Returns:
    - response_dict (dict): Dictionary containing the response from the API.
    """
    url_root = 'https://services.leadconnectorhq.com/'
    if payload:
        print(f'input payload: {payload}')
    try:
        if endpoint == 'createNote':
            endpoint_url = f'contacts/{contactId}/notes'
            request_type = 'POST'
            if payload == None:
                payload = {}
                payload['body'] = (f"Reply to SMS (contactID {contactId}) {datetime.utcnow().strftime('%Y-%m-%dT%H:%M:%SZ')}" if text==None else text)
                payload['userId'] = contactId
        elif endpoint == 'createTask':
            endpoint_url = f'contacts/{contactId}/tasks'
            request_type = 'POST'
            if payload == None:
                payload = {}
                payload['title'] = f'Send message to contact {contactId}'
                payload['body'] = text if text else f"Test task via GHL API at {datetime.utcnow().strftime('%Y-%m-%dT%H:%M:%SZ')} Pacific time"
            payload['dueDate'] = payload.get('dueDate', datetime.utcnow().strftime('%Y-%m-%dT%H:%M:%SZ'))
            payload['completed'] = False
        elif endpoint == 'sendMessage':
            endpoint_url = f'conversations/messages'
            request_type = 'POST'
            payload["contactId"] = contactId
            if payload['type'] == 'Email':
                payload['html'] = payload['message']
        elif endpoint == 'getEmailHistory':
            endpoint_url = f'conversations/search?contactId={contactId}'
            request_type = 'GET'
            payload = None
        else:
            raise ValueError("Invalid endpoint value. Valid values are 'createTask', 'createNote', 'sendMessage', and 'getEmailHistory'.")

        url = f'{url_root}{endpoint_url}'
        try:
            with open('private/auth_token_response.json') as token_file:
                token = json.load(token_file)[location]
        except:
            try:
                s3 = boto3.client('s3')
                response = s3.get_object(Bucket='ownitfit-silvhua', Key='auth_token_response.json')
                print(f'Token reponse: {response}')
                token = json.loads(response['Body'].read().decode('utf-8'))
                print(f'Token: {token} (type: {type(token)})')
                return token
            except Exception as error:
                exc_type, exc_obj, tb = sys.exc_info()
                f = tb.tb_frame
                lineno = tb.tb_lineno
                filename = f.f_code.co_filename
                print(f'Error in line {lineno} of {filename}: {str(error)}')
                return None

        # headers = {
        #     "Authorization": f"Bearer {token['access_token']}",
        #     "Version": "2021-04-15",
        #     "Content-Type": "application/json",
        #     "Accept": "application/json"
        # }


        # if request_type == 'POST':
        #     response = requests.post(
        #         url, headers=headers, 
        #         json=payload if payload else None
        #     )
        # elif request_type == 'GET':
        #     response = requests.get(
        #         url, headers=headers, 
        #         json=payload if payload else None
        #     )
        # else:
        #     raise ValueError("Invalid request type. Valid values are 'POST' and 'GET'.")

        # print(f'Status code {response.status_code}: {response.reason}')
        # data = response.json()
        # data['status_code'] = response.status_code
        # data['response_reason'] = response.reason
        # try:
        #     if endpoint == 'getEmailHistory':
        #         email_timestamp = data['conversations'][0]['dateUpdated']/1000
        #         utc_time = datetime.utcfromtimestamp(email_timestamp)
        #         pacific_time = utc_time.replace(tzinfo=pytz.utc).astimezone(pytz.timezone('US/Pacific'))
        #         email_timestamp_str = pacific_time.strftime('%Y-%m-%d %H:%M:%S')

        #         print(f'Last email sent: {email_timestamp_str} Pacific time')
        #         data['emailTimestamp_pacific'] = email_timestamp_str
        # except Exception as error:
        #     exc_type, exc_obj, tb = sys.exc_info()
        #     f = tb.tb_frame
        #     lineno = tb.tb_lineno
        #     filename = f.f_code.co_filename
        #     print(f'Error in line {lineno} of {filename}: {str(error)}')
        #     return '[Chatbot response]'
        # return data
    except Exception as error:
        exc_type, exc_obj, tb = sys.exc_info()
        f = tb.tb_frame
        lineno = tb.tb_lineno
        filename = f.f_code.co_filename
        print(f'Error in line {lineno} of {filename}: {str(error)}')
        return '[Chatbot response]'

iteration = 3.4
location = 'SamLab'
business_dict = {
    'SAM_Lab': (
        'SAM_Lab.txt', # business-specific system message
        'SAM_Lab_examples.txt', # Examples 
        'SAM_Lab_doc.md' # RAG doc
        )
}
text = 'When are you open on Sunday'
query_dict[iteration] = ghl_request(
                contactId=contactId, 
                text=text,
                endpoint='createTask', 
                payload=business_dict, 
                location=location
            )

query_dict[iteration]

# %% [markdown]
# ## 3.41

# %%
import requests
from datetime import datetime
import json
import sys
from urllib.parse import urlencode
import boto3

def ghl_request(contactId, endpoint='createTask', text=None, payload=None, location='SamLab'):
    """
    Send a message to a contact in GoHighLevel or retrieve email history.

    Parameters:
    - contactId (str): Contact ID.
    - endpoint (str): API endpoint. Valid values are 'createTask', 'createNote', 'send_message', and 'getEmailHistory'.
    - payload (dict): Dictionary containing the payload for the request.
    - params_dict (dict): Dictionary containing additional parameters for the request.
    - location (str): Location value for retrieving the authentication token.

    Example payload for sendMessage endpoint:
        
            payload = {
                "type": "Email",
                "message": f"Hi, me. This is a test message from the GHL API using Python at {timestamp} Pacific time",
                "subject": "Testing GHL API with Python threadId",
                "emailFrom": "Brian Quinlan <brian@ownitfit.com.au>",
                "threadId": 'Y0ecBIIPiHa7bpZr616G'
            }

    Returns:
    - response_dict (dict): Dictionary containing the response from the API.
    """
    url_root = 'https://services.leadconnectorhq.com/'
    if payload:
        print(f'input payload: {payload}')
    try:
        if endpoint == 'createNote':
            endpoint_url = f'contacts/{contactId}/notes'
            request_type = 'POST'
            if payload == None:
                payload = {}
                payload['body'] = (f"Reply to SMS (contactID {contactId}) {datetime.utcnow().strftime('%Y-%m-%dT%H:%M:%SZ')}" if text==None else text)
                payload['userId'] = contactId
        elif endpoint == 'createTask':
            endpoint_url = f'contacts/{contactId}/tasks'
            request_type = 'POST'
            if payload == None:
                payload = {}
                payload['title'] = f'Send message to contact {contactId}'
                payload['body'] = text if text else f"Test task via GHL API at {datetime.utcnow().strftime('%Y-%m-%dT%H:%M:%SZ')} Pacific time"
            payload['dueDate'] = payload.get('dueDate', datetime.utcnow().strftime('%Y-%m-%dT%H:%M:%SZ'))
            payload['completed'] = False
        elif endpoint == 'sendMessage':
            endpoint_url = f'conversations/messages'
            request_type = 'POST'
            payload["contactId"] = contactId
            if payload['type'] == 'Email':
                payload['html'] = payload['message']
        elif endpoint == 'getEmailHistory':
            endpoint_url = f'conversations/search?contactId={contactId}'
            request_type = 'GET'
            payload = None
        else:
            raise ValueError("Invalid endpoint value. Valid values are 'createTask', 'createNote', 'sendMessage', and 'getEmailHistory'.")

        url = f'{url_root}{endpoint_url}'
        try:
            with open('private/auth_token_response.json') as token_file:
                token = json.load(token_file)[location]
        except:
            try:
                s3 = boto3.client('s3')
                response = s3.get_object(Bucket='ownitfit-silvhua', Key='auth_token_response.json')
                print(f'Token reponse: {response}')
                token = json.loads(response['Body'].read().decode('utf-8'))[location]
                print(f'Token: {token} (type: {type(token)})')
            except Exception as error:
                exc_type, exc_obj, tb = sys.exc_info()
                f = tb.tb_frame
                lineno = tb.tb_lineno
                filename = f.f_code.co_filename
                print(f'Error in line {lineno} of {filename}: {str(error)}')
                return None

        headers = {
            "Authorization": f"Bearer {token['access_token']}",
            "Version": "2021-04-15",
            "Content-Type": "application/json",
            "Accept": "application/json"
        }


        if request_type == 'POST':
            response = requests.post(
                url, headers=headers, 
                json=payload if payload else None
            )
        elif request_type == 'GET':
            response = requests.get(
                url, headers=headers, 
                json=payload if payload else None
            )
        else:
            raise ValueError("Invalid request type. Valid values are 'POST' and 'GET'.")

        print(f'Status code {response.status_code}: {response.reason}')
        data = response.json()
        data['status_code'] = response.status_code
        data['response_reason'] = response.reason
        try:
            if endpoint == 'getEmailHistory':
                email_timestamp = data['conversations'][0]['dateUpdated']/1000
                utc_time = datetime.utcfromtimestamp(email_timestamp)
                pacific_time = utc_time.replace(tzinfo=pytz.utc).astimezone(pytz.timezone('US/Pacific'))
                email_timestamp_str = pacific_time.strftime('%Y-%m-%d %H:%M:%S')

                print(f'Last email sent: {email_timestamp_str} Pacific time')
                data['emailTimestamp_pacific'] = email_timestamp_str
        except Exception as error:
            exc_type, exc_obj, tb = sys.exc_info()
            f = tb.tb_frame
            lineno = tb.tb_lineno
            filename = f.f_code.co_filename
            print(f'Error in line {lineno} of {filename}: {str(error)}')
            return '[Chatbot response]'
        return data
    except Exception as error:
        exc_type, exc_obj, tb = sys.exc_info()
        f = tb.tb_frame
        lineno = tb.tb_lineno
        filename = f.f_code.co_filename
        print(f'Error in line {lineno} of {filename}: {str(error)}')
        return '[Chatbot response]'

iteration = 3.41
location = 'SamLab'
business_dict = {
    'SAM_Lab': (
        'SAM_Lab.txt', # business-specific system message
        'SAM_Lab_examples.txt', # Examples 
        'SAM_Lab_doc.md' # RAG doc
        )
}
text = 'When are you open on Sunday'
query_dict[iteration] = ghl_request(
                contactId=contactId, 
                text=text,
                endpoint='createTask', 
                payload=business_dict, 
                location=location
            )

query_dict[iteration]

# %% [markdown]
# ## 3.42

# %%
import requests
from datetime import datetime
import json
import sys
from urllib.parse import urlencode
import boto3

def ghl_request(contactId, endpoint='createTask', text=None, payload=None, location='SamLab'):
    """
    Send a message to a contact in GoHighLevel or retrieve email history.

    Parameters:
    - contactId (str): Contact ID.
    - endpoint (str): API endpoint. Valid values are 'createTask', 'createNote', 'send_message', and 'getEmailHistory'.
    - payload (dict): Dictionary containing the payload for the request.
    - params_dict (dict): Dictionary containing additional parameters for the request.
    - location (str): Location value for retrieving the authentication token.

    Example payload for sendMessage endpoint:
        
            payload = {
                "type": "Email",
                "message": f"Hi, me. This is a test message from the GHL API using Python at {timestamp} Pacific time",
                "subject": "Testing GHL API with Python threadId",
                "emailFrom": "Brian Quinlan <brian@ownitfit.com.au>",
                "threadId": 'Y0ecBIIPiHa7bpZr616G'
            }

    Returns:
    - response_dict (dict): Dictionary containing the response from the API.
    """
    url_root = 'https://services.leadconnectorhq.com/'
    if payload:
        print(f'input payload: {payload}')
    try:
        if endpoint == 'createNote':
            endpoint_url = f'contacts/{contactId}/notes'
            request_type = 'POST'
            if payload == None:
                payload = {}
                payload['body'] = (f"Reply to SMS (contactID {contactId}) {datetime.utcnow().strftime('%Y-%m-%dT%H:%M:%SZ')}" if text==None else text)
                payload['userId'] = contactId
        elif endpoint == 'createTask':
            endpoint_url = f'contacts/{contactId}/tasks'
            request_type = 'POST'
            if payload == None:
                payload = {}
                payload['title'] = f'Send message to contact {contactId}'
                payload['body'] = text if text else f"Test task via GHL API at {datetime.utcnow().strftime('%Y-%m-%dT%H:%M:%SZ')} Pacific time"
            payload['dueDate'] = payload.get('dueDate', datetime.utcnow().strftime('%Y-%m-%dT%H:%M:%SZ'))
            payload['completed'] = False
        elif endpoint == 'sendMessage':
            endpoint_url = f'conversations/messages'
            request_type = 'POST'
            payload["contactId"] = contactId
            if payload['type'] == 'Email':
                payload['html'] = payload['message']
        elif endpoint == 'getEmailHistory':
            endpoint_url = f'conversations/search?contactId={contactId}'
            request_type = 'GET'
            payload = None
        else:
            raise ValueError("Invalid endpoint value. Valid values are 'createTask', 'createNote', 'sendMessage', and 'getEmailHistory'.")

        url = f'{url_root}{endpoint_url}'
        try:
            with open('private/auth_token_response.json') as token_file:
                token = json.load(token_file)[location]
        except:
            try:
                s3 = boto3.client('s3')
                response = s3.get_object(Bucket='ownitfit-silvhua', Key='auth_token_response.json')
                print(f'Token reponse: {response}')
                token = json.loads(response['Body'].read().decode('utf-8'))[location]
                print(f'Token: {token} (type: {type(token)})')
            except Exception as error:
                exc_type, exc_obj, tb = sys.exc_info()
                f = tb.tb_frame
                lineno = tb.tb_lineno
                filename = f.f_code.co_filename
                print(f'Error in line {lineno} of {filename}: {str(error)}')
                return None

        headers = {
            "Authorization": f"Bearer {token['access_token']}",
            "Version": "2021-04-15",
            "Content-Type": "application/json",
            "Accept": "application/json"
        }


        if request_type == 'POST':
            response = requests.post(
                url, headers=headers, 
                json=payload if payload else None
            )
        elif request_type == 'GET':
            response = requests.get(
                url, headers=headers, 
                json=payload if payload else None
            )
        else:
            raise ValueError("Invalid request type. Valid values are 'POST' and 'GET'.")

        print(f'Status code {response.status_code}: {response.reason}')
        data = response.json()
        data['status_code'] = response.status_code
        data['response_reason'] = response.reason
        try:
            if endpoint == 'getEmailHistory':
                email_timestamp = data['conversations'][0]['dateUpdated']/1000
                utc_time = datetime.utcfromtimestamp(email_timestamp)
                pacific_time = utc_time.replace(tzinfo=pytz.utc).astimezone(pytz.timezone('US/Pacific'))
                email_timestamp_str = pacific_time.strftime('%Y-%m-%d %H:%M:%S')

                print(f'Last email sent: {email_timestamp_str} Pacific time')
                data['emailTimestamp_pacific'] = email_timestamp_str
        except Exception as error:
            exc_type, exc_obj, tb = sys.exc_info()
            f = tb.tb_frame
            lineno = tb.tb_lineno
            filename = f.f_code.co_filename
            print(f'Error in line {lineno} of {filename}: {str(error)}')
            return '[Chatbot response]'
        return data
    except Exception as error:
        exc_type, exc_obj, tb = sys.exc_info()
        f = tb.tb_frame
        lineno = tb.tb_lineno
        filename = f.f_code.co_filename
        print(f'Error in line {lineno} of {filename}: {str(error)}')
        return '[Chatbot response]'

iteration = 3.2
location = 'SamLab'
business_dict = {
    'SamLab': (
        'SAM_Lab.txt', # business-specific system message
        'SAM_Lab_examples.txt', # Examples 
        'SAM_Lab_doc.md' # RAG doc
        )
}
text = 'When are you open on Sunday'
query_dict[iteration] = ghl_request(
                contactId=contactId, 
                text=text,
                endpoint='createTask', 
                payload=business_dict[location], 
                location=location
            )

query_dict[iteration]
# Out:
# input payload: ('SAM_Lab.txt', 'SAM_Lab_examples.txt', 'SAM_Lab_doc.md')
# Error in line 50 of C:\Users\silvh\AppData\Local\Temp\ipykernel_8448\1069257900.py: 'tuple' object has no attribute 'get'
# '[Chatbot response]'

# %% [markdown]
# ## 3.43

# %%
business_dict = {
    'SamLab': (
        'SAM_Lab.txt', # business-specific system message
        'SAM_Lab_examples.txt', # Examples 
        'SAM_Lab_doc.md' # RAG doc
        )
}
if len(business_dict['SamLab']) > 3:
    print(business_dict['SamLab'][4] ) 
else: 
    business_dict['SamLab'][2]

# %%
test = business_dict['SamLab'][3] if len(business_dict['SamLab']) > 3 else business_dict['SamLab'][2]
test
# Out:
# 'SAM_Lab_doc.md'

# %%
import requests
from datetime import datetime
import json
import sys
from urllib.parse import urlencode
import boto3

def ghl_request(contactId, endpoint='createTask', text=None, payload=None, location='SamLab'):
    """
    Send a message to a contact in GoHighLevel or retrieve email history.

    Parameters:
    - contactId (str): Contact ID.
    - endpoint (str): API endpoint. Valid values are 'createTask', 'createNote', 'send_message', and 'getEmailHistory'.
    - payload (dict): Dictionary containing the payload for the request.
    - params_dict (dict): Dictionary containing additional parameters for the request.
    - location (str): Location value for retrieving the authentication token.

    Example payload for sendMessage endpoint:
        
            payload = {
                "type": "Email",
                "message": f"Hi, me. This is a test message from the GHL API using Python at {timestamp} Pacific time",
                "subject": "Testing GHL API with Python threadId",
                "emailFrom": "Brian Quinlan <brian@ownitfit.com.au>",
                "threadId": 'Y0ecBIIPiHa7bpZr616G'
            }

    Returns:
    - response_dict (dict): Dictionary containing the response from the API.
    """
    url_root = 'https://services.leadconnectorhq.com/'
    if payload:
        print(f'input payload: {payload}')
    try:
        if endpoint == 'createNote':
            endpoint_url = f'contacts/{contactId}/notes'
            request_type = 'POST'
            if payload == None:
                payload = {}
                payload['body'] = (f"Reply to SMS (contactID {contactId}) {datetime.utcnow().strftime('%Y-%m-%dT%H:%M:%SZ')}" if text==None else text)
                payload['userId'] = contactId
        elif endpoint == 'createTask':
            endpoint_url = f'contacts/{contactId}/tasks'
            request_type = 'POST'
            if payload == None:
                payload = {}
                payload['title'] = f'Send message to contact {contactId}'
                payload['body'] = text if text else f"Test task via GHL API at {datetime.utcnow().strftime('%Y-%m-%dT%H:%M:%SZ')} Pacific time"
            payload['dueDate'] = payload[3] if len(payload) > 3 else datetime.utcnow().strftime('%Y-%m-%dT%H:%M:%SZ')
            payload['completed'] = False
        elif endpoint == 'sendMessage':
            endpoint_url = f'conversations/messages'
            request_type = 'POST'
            payload["contactId"] = contactId
            if payload['type'] == 'Email':
                payload['html'] = payload['message']
        elif endpoint == 'getEmailHistory':
            endpoint_url = f'conversations/search?contactId={contactId}'
            request_type = 'GET'
            payload = None
        else:
            raise ValueError("Invalid endpoint value. Valid values are 'createTask', 'createNote', 'sendMessage', and 'getEmailHistory'.")

        url = f'{url_root}{endpoint_url}'
        try:
            with open('private/auth_token_response.json') as token_file:
                token = json.load(token_file)[location]
        except:
            try:
                s3 = boto3.client('s3')
                response = s3.get_object(Bucket='ownitfit-silvhua', Key='auth_token_response.json')
                print(f'Token reponse: {response}')
                token = json.loads(response['Body'].read().decode('utf-8'))[location]
                print(f'Token: {token} (type: {type(token)})')
            except Exception as error:
                exc_type, exc_obj, tb = sys.exc_info()
                f = tb.tb_frame
                lineno = tb.tb_lineno
                filename = f.f_code.co_filename
                print(f'Error in line {lineno} of {filename}: {str(error)}')
                return None

        headers = {
            "Authorization": f"Bearer {token['access_token']}",
            "Version": "2021-04-15",
            "Content-Type": "application/json",
            "Accept": "application/json"
        }


        if request_type == 'POST':
            response = requests.post(
                url, headers=headers, 
                json=payload if payload else None
            )
        elif request_type == 'GET':
            response = requests.get(
                url, headers=headers, 
                json=payload if payload else None
            )
        else:
            raise ValueError("Invalid request type. Valid values are 'POST' and 'GET'.")

        print(f'Status code {response.status_code}: {response.reason}')
        data = response.json()
        data['status_code'] = response.status_code
        data['response_reason'] = response.reason
        try:
            if endpoint == 'getEmailHistory':
                email_timestamp = data['conversations'][0]['dateUpdated']/1000
                utc_time = datetime.utcfromtimestamp(email_timestamp)
                pacific_time = utc_time.replace(tzinfo=pytz.utc).astimezone(pytz.timezone('US/Pacific'))
                email_timestamp_str = pacific_time.strftime('%Y-%m-%d %H:%M:%S')

                print(f'Last email sent: {email_timestamp_str} Pacific time')
                data['emailTimestamp_pacific'] = email_timestamp_str
        except Exception as error:
            exc_type, exc_obj, tb = sys.exc_info()
            f = tb.tb_frame
            lineno = tb.tb_lineno
            filename = f.f_code.co_filename
            print(f'Error in line {lineno} of {filename}: {str(error)}')
            return '[Chatbot response]'
        return data
    except Exception as error:
        exc_type, exc_obj, tb = sys.exc_info()
        f = tb.tb_frame
        lineno = tb.tb_lineno
        filename = f.f_code.co_filename
        print(f'Error in line {lineno} of {filename}: {str(error)}')
        return '[Chatbot response]'

iteration = 3.43
location = 'SamLab'
business_dict = {
    'SamLab': (
        'SAM_Lab.txt', # business-specific system message
        'SAM_Lab_examples.txt', # Examples 
        'SAM_Lab_doc.md' # RAG doc
        )
}
text = 'When are you open on Sunday'
query_dict[iteration] = ghl_request(
                contactId=contactId, 
                text=text,
                endpoint='createTask', 
                payload=business_dict[location], 
                location=location
            )

query_dict[iteration]
# Out:
# input payload: ('SAM_Lab.txt', 'SAM_Lab_examples.txt', 'SAM_Lab_doc.md')
# Error in line 50 of C:\Users\silvh\AppData\Local\Temp\ipykernel_8448\2832977616.py: 'tuple' object does not support item assignment
# '[Chatbot response]'

# %% [markdown]
# ## 3.44

# %%
import requests
from datetime import datetime
import json
import sys
from urllib.parse import urlencode
import boto3

def ghl_request(contactId, endpoint='createTask', text=None, payload=None, location='SamLab'):
    """
    Send a message to a contact in GoHighLevel or retrieve email history.

    Parameters:
    - contactId (str): Contact ID.
    - endpoint (str): API endpoint. Valid values are 'createTask', 'createNote', 'send_message', and 'getEmailHistory'.
    - payload (dict): Dictionary containing the payload for the request.
    - params_dict (dict): Dictionary containing additional parameters for the request.
    - location (str): Location value for retrieving the authentication token.

    Example payload for sendMessage endpoint:
        
            payload = {
                "type": "Email",
                "message": f"Hi, me. This is a test message from the GHL API using Python at {timestamp} Pacific time",
                "subject": "Testing GHL API with Python threadId",
                "emailFrom": "Brian Quinlan <brian@ownitfit.com.au>",
                "threadId": 'Y0ecBIIPiHa7bpZr616G'
            }

    Returns:
    - response_dict (dict): Dictionary containing the response from the API.
    """
    url_root = 'https://services.leadconnectorhq.com/'
    if payload:
        print(f'input payload: {payload}')
    try:
        if endpoint == 'createNote':
            endpoint_url = f'contacts/{contactId}/notes'
            request_type = 'POST'
            if payload == None:
                payload = {}
                payload['body'] = (f"Reply to SMS (contactID {contactId}) {datetime.utcnow().strftime('%Y-%m-%dT%H:%M:%SZ')}" if text==None else text)
                payload['userId'] = contactId
        elif endpoint == 'createTask':
            endpoint_url = f'contacts/{contactId}/tasks'
            request_type = 'POST'
            if payload == None:
                payload = {}
                payload['title'] = f'Send message to contact {contactId}'
                payload['body'] = text if text else f"Test task via GHL API at {datetime.utcnow().strftime('%Y-%m-%dT%H:%M:%SZ')} Pacific time"
            payload['dueDate'] = payload[3] if len(payload) > 3 else datetime.utcnow().strftime('%Y-%m-%dT%H:%M:%SZ')
            payload['completed'] = False
        elif endpoint == 'sendMessage':
            endpoint_url = f'conversations/messages'
            request_type = 'POST'
            payload["contactId"] = contactId
            if payload['type'] == 'Email':
                payload['html'] = payload['message']
        elif endpoint == 'getEmailHistory':
            endpoint_url = f'conversations/search?contactId={contactId}'
            request_type = 'GET'
            payload = None
        else:
            raise ValueError("Invalid endpoint value. Valid values are 'createTask', 'createNote', 'sendMessage', and 'getEmailHistory'.")

        url = f'{url_root}{endpoint_url}'
        try:
            with open('private/auth_token_response.json') as token_file:
                token = json.load(token_file)[location]
        except:
            try:
                s3 = boto3.client('s3')
                response = s3.get_object(Bucket='ownitfit-silvhua', Key='auth_token_response.json')
                print(f'Token reponse: {response}')
                token = json.loads(response['Body'].read().decode('utf-8'))[location]
                print(f'Token: {token} (type: {type(token)})')
            except Exception as error:
                exc_type, exc_obj, tb = sys.exc_info()
                f = tb.tb_frame
                lineno = tb.tb_lineno
                filename = f.f_code.co_filename
                print(f'Error in line {lineno} of {filename}: {str(error)}')
                return None

        headers = {
            "Authorization": f"Bearer {token['access_token']}",
            "Version": "2021-04-15",
            "Content-Type": "application/json",
            "Accept": "application/json"
        }


        if request_type == 'POST':
            response = requests.post(
                url, headers=headers, 
                json=payload if payload else None
            )
        elif request_type == 'GET':
            response = requests.get(
                url, headers=headers, 
                json=payload if payload else None
            )
        else:
            raise ValueError("Invalid request type. Valid values are 'POST' and 'GET'.")

        print(f'Status code {response.status_code}: {response.reason}')
        data = response.json()
        data['status_code'] = response.status_code
        data['response_reason'] = response.reason
        try:
            if endpoint == 'getEmailHistory':
                email_timestamp = data['conversations'][0]['dateUpdated']/1000
                utc_time = datetime.utcfromtimestamp(email_timestamp)
                pacific_time = utc_time.replace(tzinfo=pytz.utc).astimezone(pytz.timezone('US/Pacific'))
                email_timestamp_str = pacific_time.strftime('%Y-%m-%d %H:%M:%S')

                print(f'Last email sent: {email_timestamp_str} Pacific time')
                data['emailTimestamp_pacific'] = email_timestamp_str
        except Exception as error:
            exc_type, exc_obj, tb = sys.exc_info()
            f = tb.tb_frame
            lineno = tb.tb_lineno
            filename = f.f_code.co_filename
            print(f'Error in line {lineno} of {filename}: {str(error)}')
            return '[Chatbot response]'
        return data
    except Exception as error:
        exc_type, exc_obj, tb = sys.exc_info()
        f = tb.tb_frame
        lineno = tb.tb_lineno
        filename = f.f_code.co_filename
        print(f'Error in line {lineno} of {filename}: {str(error)}')
        return '[Chatbot response]'

iteration = 3.44
location = 'SamLab'
business_dict = {
    'SamLab': (
        'SAM_Lab.txt', # business-specific system message
        'SAM_Lab_examples.txt', # Examples 
        'SAM_Lab_doc.md' # RAG doc
        )
}
text = 'When are you open on Sunday'
query_dict[iteration] = ghl_request(
                contactId=contactId, 
                text=text,
                endpoint='createTask', 
                payload=None, 
                location=location
            )

query_dict[iteration]

# %%
iteration = 3.441
location = 'SamLab'
business_dict = {
    'SamLab': (
        'SAM_Lab.txt', # business-specific system message
        'SAM_Lab_examples.txt', # Examples 
        'SAM_Lab_doc.md' # RAG doc
        )
}
text = 'When are you open on Sunday'
query_dict[iteration] = ghl_request(
                contactId=contactId, 
                text=text,
                endpoint='createTask', 
                payload=None, 
                location=location
            )

query_dict[iteration]

# %% [markdown]
# # *End of Page*
