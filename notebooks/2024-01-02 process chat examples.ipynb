# %% [markdown]
# # Title
# []()

# %%
import sys
sys.path.append(r"/home/silvhua/custom_python")
from silvhua import *

# %%
# set the option to wrap text within cells
pd.set_option('display.max_colwidth', 100)
# pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 20)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %%
text_dict = dict()

# %% [markdown]
# # Iteration 1

# %%
def load_conversation(id, filepath='/home/silvhua/repositories/GHL-chat/data/chat_examples/Coach_Mcloone'):
    
    filename = f'{filepath}/'.replace('\\','/') + f'{id}.txt'
    with open(filename, 'r', encoding='utf-8') as file:
        text = file.read()
    return text

id = 1525
text_dict[id] = load_conversation(id=id)
text_dict[id]

# %% [markdown]
# # Iteration 2

# %%
import re

def load_conversation(id, filepath='/home/silvhua/repositories/GHL-chat/data/chat_examples/Coach_Mcloone'):
    
    filename = f'{filepath}/'.replace('\\','/') + f'{id}.txt'
    with open(filename, 'r', encoding='utf-8') as file:
        text = file.read()
    return text

def annotate_conversation(**kwargs):
    text = load_conversation(**kwargs)
    text = f'Contact ID {id}:\n\t' + re.sub(r'\n', r'\n\t', text)
    text = re.sub(r'\d\d:\d\d\n\t\?', 'OutboundMessage:', text)
    text = re.sub(r'\d\d:\d\d\n+', 'InboundMessage:', text)
    return text

id = 1525
text_dict[id] = annotate_conversation(id=id)

# %% [markdown]
# ## 2.1

# %%
import os
import re

def load_conversation(id, filepath='/home/silvhua/repositories/GHL-chat/data/chat_examples/Coach_Mcloone'):
    
    filename = f'{filepath}/'.replace('\\','/') + f'{id}.txt'
    with open(filename, 'r', encoding='utf-8') as file:
        text = file.read()
    return text

def annotate_conversation(**kwargs):
    text = load_conversation(**kwargs)
    text = f'Contact ID {id}:\n\t' + re.sub(r'\n', r'\n\t', text)
    text = re.sub(r'\d\d:\d\d\n\t\?', 'OutboundMessage:', text)
    text = re.sub(r'\d\d:\d\d\n+', 'InboundMessage:', text)
    return text

def create_chat_examples(directory='/home/silvhua/repositories/GHL-chat/data/chat_examples/Coach_Mcloone'):
    """
    Iterate through all .txt files in a directory to create a list of the 
    results of the annotate_conversation function. Each result is appended 
    to the list.
    Join the elements of the list, separated by newlines, to create a long string.
    """

    chat_examples = []
    for filename in os.listdir(directory):
        if filename.endswith('.txt'):
            id = filename.split('.')[0]
            text = annotate_conversation(id=id, filepath=directory)
            chat_examples.append(text)
    result = ''.join([f"{example}\n\n" for example in chat_examples])
    return result
    


id = 1525
text_string = create_chat_examples()

# %%
print(text_string)
# Out:
# Contact ID 1525:
# 	OutboundMessage:
# 	Hey Sam, thanks for commenting on my post! Here's the link!
#
# 	https://drive.google.com/file/d/1seBGT5OLlA7jmsrvLShBRHhkpJ5RohQd/view
#
# 	OutboundMessage:
# 	This is the tried and tested method I’ve used with my current clients to help them achieve epic results 💪 I'm curious, are you also currently on a health and fitness journey or looking to start one?
#
# 	InboundMessage:
# 	I’m on one i was 150kgs for almost 30 years I lost 70kgs on my own 2019-2020 in 18months. I maintained for a short while then I had a marriage breakdown. In the last year I have put on 40kilos and I have just lost my job. I am at rock bottom. I need my confidence back and learn once and for all how to manage my weight.
#
# 	OutboundMessage:
# ...

# %% [markdown]
# ## 2.2

# %%
import os
import re

def load_conversation(id, filepath='/home/silvhua/repositories/GHL-chat/data/chat_examples/Coach_Mcloone'):
    
    filename = f'{filepath}/'.replace('\\','/') + f'{id}.txt'
    with open(filename, 'r', encoding='utf-8') as file:
        text = file.read()
    return text

def annotate_conversation(**kwargs):
    text = load_conversation(**kwargs)
    text = f'Contact ID {id}:\n\t' + re.sub(r'\n', r'\n\t', text)
    text = re.sub(r'\d\d:\d\d\n\t\?', 'OutboundMessage:', text)
    text = re.sub(r'\d\d:\d\d\n+', 'InboundMessage:', text)
    return text

def create_chat_examples(directory='/home/silvhua/repositories/GHL-chat/data/chat_examples/Coach_Mcloone'):
    """
    Iterate through all .txt files in a directory to create a list of the 
    results of the annotate_conversation function. Each result is appended 
    to the list.
    Join the elements of the list, separated by newlines, to create a long string.
    """

    chat_examples = dict()
    for filename in os.listdir(directory):
        if filename.endswith('.txt'):
            id = filename.split('.')[0]
            text = annotate_conversation(id=id, filepath=directory)
            chat_examples[id] = text
    return chat_examples
    


id = 1525
chat_examples = create_chat_examples()

# %%
save_to_json(
    chat_examples, filename=None, description='Coach_Mcloone_chat_examples', append_version=False,
    path='/home/silvhua/repositories/GHL-chat/data/chat_examples/Coach_Mcloone'
)
# Out:
# Object saved as JSON: /home/silvhua/repositories/GHL-chat/data/chat_examples/Coach_Mcloone/Coach_Mcloone_chat_examples_2024-01-02_2304.json

# %% [markdown]
# ### 2.21

# %%
import os
import re

def load_conversation(id, filepath='/home/silvhua/repositories/GHL-chat/data/chat_examples/Coach_Mcloone'):
    
    filename = f'{filepath}/'.replace('\\','/') + f'{id}.txt'
    with open(filename, 'r', encoding='utf-8') as file:
        text = file.read()
    return text

def annotate_conversation(**kwargs):
    text = load_conversation(**kwargs)
    # text = f'Contact ID {id}:\n\t' + re.sub(r'\n', r'\n\t', text)
    text = re.sub(r'\n', r'\n\t', text)
    text = re.sub(r'\d\d:\d\d\n\t\?', 'OutboundMessage:', text)
    text = re.sub(r'\d\d:\d\d\n+', 'InboundMessage:', text)
    return text

def create_chat_examples(directory='/home/silvhua/repositories/GHL-chat/data/chat_examples/Coach_Mcloone'):
    """
    Iterate through all .txt files in a directory to create a list of the 
    results of the annotate_conversation function. Each result is appended 
    to the list.
    Join the elements of the list, separated by newlines, to create a long string.
    """

    chat_examples = dict()
    for filename in os.listdir(directory):
        if filename.endswith('.txt'):
            id = filename.split('.')[0]
            text = annotate_conversation(id=id, filepath=directory)
            chat_examples[id] = text
    return chat_examples
    


id = 1525
chat_examples = create_chat_examples()

# %%
save_to_json(
    chat_examples, filename=None, description='Coach_Mcloone_chat_examples', append_version=False,
    path='/home/silvhua/repositories/GHL-chat/data/chat_examples/Coach_Mcloone'
)
# Out:
# Object saved as JSON: /home/silvhua/repositories/GHL-chat/data/chat_examples/Coach_Mcloone/Coach_Mcloone_chat_examples_2024-01-02_2306.json

# %% [markdown]
# # Iteration 3

# %%
import os
import re

def load_conversation(contact_id, filepath='/home/silvhua/repositories/GHL-chat/data/chat_examples/Coach_Mcloone'):
    
    filename = f'{filepath}/'.replace('\\','/') + f'{contact_id}.txt'
    with open(filename, 'r', encoding='utf-8') as file:
        text = file.read()
    return text

def annotate_conversation(contact_id, filepath):
    text = load_conversation(contact_id, filepath)
    text = f'Contact ID {contact_id}:\n\t' + re.sub(r'\n', r'\n\t', text)
    text = re.sub(r'\d\d:\d\d\n\t\?', 'OutboundMessage:', text)
    text = re.sub(r'\d\d:\d\d\n+', 'InboundMessage:', text)
    return text

def create_chat_examples(directory='/home/silvhua/repositories/GHL-chat/data/chat_examples/Coach_Mcloone'):
    """
    Iterate through all .txt files in a directory to create a list of the 
    results of the annotate_conversation function. Each result is appended 
    to the list.
    Join the elements of the list, separated by newlines, to create a long string.
    """

    chat_examples = []
    filenames = sorted(os.listdir(directory))
    for filename in filenames:
        if filename.endswith('.txt'):
            contact_id = filename.split('.')[0]
            text = annotate_conversation(contact_id=contact_id, filepath=directory)
            chat_examples.append(text)
    result = ''.join([f"{example}\n\n" for example in chat_examples])
    return result
    
text_string = create_chat_examples()
print(text_string)
# Out:
# Contact ID 1425:
# 	Thanks <name> 🙏 I'll give you a personal message here shortly.
#
# 	Just quickly, what's your current height and weight right now?
#
# 	PS: Yes this message is automated, (I know you probably guessed that) but if you reply here, I'll get back to you as soon as I'm online next 😊
#
# 	InboundMessage:
# 	5ft 10 and 84kg 😞
# 	I’m following a healthy eating plan that I’m thoroughly enjoying. I’m perimenopausal, on HRT and I just can’t shift the extra weight that piled on so quickly. I’m not afraid of working hard at things but it’s so disheartening and upsetting when nothing I’m doing seems to be working. Thank you for taking the time to read my message. Kind regards, <name>
#
# 	OutboundMessage:
# 	Hey <name>, it's Amanda, creator of the Strong and Sassy Programme. I’m sorry for those computer generated responses but you have me now. 🤗
#
# 	OutboundMessage:
# ...

# %% [markdown]
# # Save text_string to text file

# %%
save_text(
    text_string, 'CoachMcloone', path='../data/chat_examples',append_version=True
    )
# Out:
# File saved:  ../data/chat_examples/CoachMcloone2024-01-04_2238.txt
# 	Time completed: 2024-01-04 22:38:14.375711

# %% [markdown]
# # *End of Page*
